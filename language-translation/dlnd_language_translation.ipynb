# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    source_sentences = source_text.split('\n')
    source_id_text = []
    for sentence in source_sentences:
        source_id_text.append([source_vocab_to_int[w] for w in sentence.split()])
        
    target_sentences = target_text.split('\n')
    target_id_text = []
    for sentence in target_sentences:
        target_id_text.append([target_vocab_to_int[w] for w in sentence.split()] + [target_vocab_to_int['<EOS>']])
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.4.0
# C:\Users\alceu\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    inputs = tf.placeholder(dtype=tf.int32, shape=[None, None], name='input')
    targets = tf.placeholder(dtype=tf.int32, shape=[None, None], name='targets')
    learn_rate = tf.placeholder(dtype=tf.float32, shape=[], name='learning_rate')
    keep_prob = tf.placeholder(dtype=tf.float32, shape=[], name='keep_prob')
    target_seq_len = tf.placeholder(dtype=tf.int32, shape=[None], name='target_sequence_length')
    max_target_seq_len = tf.reduce_max(target_seq_len, name='max_target_len')
    source_seq_len = tf.placeholder(dtype=tf.int32, shape=[None], name='source_sequence_length')
    
    
    return (inputs, 
            targets, 
            learn_rate, 
            keep_prob, 
            target_seq_len, 
            max_target_seq_len, 
            source_seq_len)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size, go_token='<GO>'):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # Remove last word ID.
    target_data = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    
    # Add the ID of the go_token to the beginning of each batch.
    go_id = target_vocab_to_int[go_token]
    target_data = tf.concat([tf.fill([batch_size, 1], go_id), target_data], 1)
    
    return target_data

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    embed = tf.contrib.layers.embed_sequence(rnn_inputs, 
                                             vocab_size=source_vocab_size,
                                             embed_dim=encoding_embedding_size)
    lstm_cell_list = []
    for _ in range(num_layers):
        # TODO: dropout.
        lstm = tf.contrib.rnn.LSTMCell(rnn_size)
        lstm = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
        lstm_cell_list.append(lstm)
    cell = tf.contrib.rnn.MultiRNNCell(lstm_cell_list)
    
    rnn_output, rnn_state = tf.nn.dynamic_rnn(cell, embed, 
                                              sequence_length=source_sequence_length, 
                                              dtype=tf.float32)
    return rnn_output, rnn_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
#
# Architecture of the training decoder (taken from the seq2seq notebook):
#
# <img src="images/sequence-to-sequence-training-decoder.png"/>
#
#
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # Helper for the training process. Used by BasicDecoder to read inputs.
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input,
                                                        sequence_length=target_sequence_length,
                                                        time_major=False)
    
    # Basic decoder.
    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                       training_helper,
                                                       encoder_state,
                                                       output_layer) 
    
    # Perform dynamic decoding using the decoder
    training_decoder_output = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                                                impute_finished=True,
                                                                maximum_iterations=max_summary_length)[0]
    
    return training_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS ID
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # Tensor with the start tokens.
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), 
                                       [batch_size], 
                                       name='start_tokens')
    
    # Helper for the inference process.
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                                start_tokens,
                                                                end_of_sequence_id)
    # Basic decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                        inference_helper,
                                                        encoder_state,
                                                        output_layer)
    
    # Perform dynamic decoding using the decoder
    inf_dec_output = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                       impute_finished=True,
                                                       maximum_iterations=max_target_sequence_length)[0]
    return inf_dec_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    with tf.variable_scope("decoder_lstm"):
        # Embed target sequences which are in the dec_inputs tensor.
        dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
        dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
        # Construct the decoder LSTM cell.
        lstm_cell_list = []
        for _ in range(num_layers):
            lstm = tf.contrib.rnn.LSTMCell(rnn_size)
            lstm = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
            lstm_cell_list.append(lstm)
        dec_cell = tf.contrib.rnn.MultiRNNCell(lstm_cell_list)
        dec_output, dec_state = tf.nn.dynamic_rnn(dec_cell, dec_embed_input, 
                                                  sequence_length=target_sequence_length, 
                                                  dtype=tf.float32)
    
    # Create an output layer to map the outputs of the decoder to the elements of our vocabulary.
    #   Let's use the rule of std_dev = 1/sqrt(n), with n as the number of inputs to a neuron.
    ini_std_dev = 1.0/np.sqrt(target_vocab_size)
    output_layer = tf.layers.Dense(target_vocab_size, 
                                   kernel_initializer=tf.truncated_normal_initializer(mean=0.0, stddev=ini_std_dev))
    
    # Get logits.
    with tf.variable_scope("decode"):
        train_dec_out = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                                             target_sequence_length, max_target_sequence_length, 
                                             output_layer, keep_prob)
    with tf.variable_scope("decode", reuse=True):
        start_of_sequence_id = target_vocab_to_int['<GO>']
        end_of_sequence_id = target_vocab_to_int['<EOS>']
        infer_dec_out = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, 
                                             start_of_sequence_id, end_of_sequence_id, 
                                             max_target_sequence_length, target_vocab_size, 
                                             output_layer, batch_size, keep_prob)
    return train_dec_out, infer_dec_out



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    enc_output, enc_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, 
                                           source_sequence_length, source_vocab_size, enc_embedding_size)
    target_data = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    return decoding_layer(target_data, enc_state, target_sequence_length, max_target_sentence_length, 
                          rnn_size, num_layers, target_vocab_to_int, 
                          target_vocab_size, batch_size, keep_prob, dec_embedding_size)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 500
# RNN Size
rnn_size = 256
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 300
decoding_embedding_size = 300
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 0.8
display_step = 6

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    6/275 - Train Accuracy: 0.2954, Validation Accuracy: 0.3280, Loss: 3.3930
# Epoch   0 Batch   12/275 - Train Accuracy: 0.3304, Validation Accuracy: 0.3864, Loss: 3.1675
# Epoch   0 Batch   18/275 - Train Accuracy: 0.3627, Validation Accuracy: 0.3939, Loss: 2.7441
# Epoch   0 Batch   24/275 - Train Accuracy: 0.4211, Validation Accuracy: 0.4421, Loss: 2.5329
# Epoch   0 Batch   30/275 - Train Accuracy: 0.4155, Validation Accuracy: 0.4679, Loss: 2.4630
# Epoch   0 Batch   36/275 - Train Accuracy: 0.4826, Validation Accuracy: 0.5045, Loss: 2.2016
# Epoch   0 Batch   42/275 - Train Accuracy: 0.4415, Validation Accuracy: 0.4635, Loss: 2.0793
# Epoch   0 Batch   48/275 - Train Accuracy: 0.5443, Validation Accuracy: 0.5364, Loss: 1.8337
# Epoch   0 Batch   54/275 - Train Accuracy: 0.5224, Validation Accuracy: 0.5631, Loss: 1.9001
# Epoch   0 Batch   60/275 - Train Accuracy: 0.5656, Validation Accuracy: 0.5784, Loss: 1.6433
# Epoch   0 Batch   66/275 - Train Accuracy: 0.5588, Validation Accuracy: 0.5737, Loss: 1.5292
# Epoch   0 Batch   72/275 - Train Accuracy: 0.5682, Validation Accuracy: 0.5727, Loss: 1.3945
# Epoch   0 Batch   78/275 - Train Accuracy: 0.5449, Validation Accuracy: 0.5737, Loss: 1.3319
# Epoch   0 Batch   84/275 - Train Accuracy: 0.5901, Validation Accuracy: 0.5902, Loss: 1.1502
# Epoch   0 Batch   90/275 - Train Accuracy: 0.5697, Validation Accuracy: 0.5801, Loss: 1.1041
# Epoch   0 Batch   96/275 - Train Accuracy: 0.5164, Validation Accuracy: 0.5562, Loss: 1.0135
# Epoch   0 Batch  102/275 - Train Accuracy: 0.5738, Validation Accuracy: 0.5784, Loss: 0.9043
# Epoch   0 Batch  108/275 - Train Accuracy: 0.5574, Validation Accuracy: 0.5892, Loss: 0.8736
# Epoch   0 Batch  114/275 - Train Accuracy: 0.5593, Validation Accuracy: 0.5705, Loss: 0.8005
# Epoch   0 Batch  120/275 - Train Accuracy: 0.5824, Validation Accuracy: 0.6076, Loss: 0.7654
# Epoch   0 Batch  126/275 - Train Accuracy: 0.5808, Validation Accuracy: 0.6135, Loss: 0.7643
# Epoch   0 Batch  132/275 - Train Accuracy: 0.6122, Validation Accuracy: 0.6256, Loss: 0.6915
# Epoch   0 Batch  138/275 - Train Accuracy: 0.5890, Validation Accuracy: 0.6199, Loss: 0.7193
# Epoch   0 Batch  144/275 - Train Accuracy: 0.6386, Validation Accuracy: 0.6438, Loss: 0.6500
# Epoch   0 Batch  150/275 - Train Accuracy: 0.6407, Validation Accuracy: 0.6345, Loss: 0.5887
# Epoch   0 Batch  156/275 - Train Accuracy: 0.6276, Validation Accuracy: 0.6409, Loss: 0.6092
# Epoch   0 Batch  162/275 - Train Accuracy: 0.6543, Validation Accuracy: 0.6524, Loss: 0.5889
# Epoch   0 Batch  168/275 - Train Accuracy: 0.6409, Validation Accuracy: 0.6572, Loss: 0.5600
# Epoch   0 Batch  174/275 - Train Accuracy: 0.6610, Validation Accuracy: 0.6605, Loss: 0.5456
# Epoch   0 Batch  180/275 - Train Accuracy: 0.6501, Validation Accuracy: 0.6665, Loss: 0.5370
# Epoch   0 Batch  186/275 - Train Accuracy: 0.6446, Validation Accuracy: 0.6684, Loss: 0.5243
# Epoch   0 Batch  192/275 - Train Accuracy: 0.6628, Validation Accuracy: 0.6788, Loss: 0.5141
# Epoch   0 Batch  198/275 - Train Accuracy: 0.6858, Validation Accuracy: 0.6821, Loss: 0.4794
# Epoch   0 Batch  204/275 - Train Accuracy: 0.6658, Validation Accuracy: 0.6885, Loss: 0.4729
# Epoch   0 Batch  210/275 - Train Accuracy: 0.6765, Validation Accuracy: 0.6856, Loss: 0.4588
# Epoch   0 Batch  216/275 - Train Accuracy: 0.6838, Validation Accuracy: 0.7115, Loss: 0.4573
# Epoch   0 Batch  222/275 - Train Accuracy: 0.6786, Validation Accuracy: 0.7125, Loss: 0.4478
# Epoch   0 Batch  228/275 - Train Accuracy: 0.7221, Validation Accuracy: 0.7175, Loss: 0.4119
# Epoch   0 Batch  234/275 - Train Accuracy: 0.7477, Validation Accuracy: 0.7363, Loss: 0.3891
# Epoch   0 Batch  240/275 - Train Accuracy: 0.7403, Validation Accuracy: 0.7417, Loss: 0.3946
# Epoch   0 Batch  246/275 - Train Accuracy: 0.7629, Validation Accuracy: 0.7476, Loss: 0.3440
# Epoch   0 Batch  252/275 - Train Accuracy: 0.7416, Validation Accuracy: 0.7460, Loss: 0.3632
# Epoch   0 Batch  258/275 - Train Accuracy: 0.7577, Validation Accuracy: 0.7506, Loss: 0.3594
# Epoch   0 Batch  264/275 - Train Accuracy: 0.7494, Validation Accuracy: 0.7685, Loss: 0.3364
# Epoch   0 Batch  270/275 - Train Accuracy: 0.7454, Validation Accuracy: 0.7709, Loss: 0.3545
# Epoch   1 Batch    6/275 - Train Accuracy: 0.7815, Validation Accuracy: 0.7727, Loss: 0.3106
# Epoch   1 Batch   12/275 - Train Accuracy: 0.7746, Validation Accuracy: 0.7937, Loss: 0.3161
# Epoch   1 Batch   18/275 - Train Accuracy: 0.7963, Validation Accuracy: 0.8042, Loss: 0.2830
# Epoch   1 Batch   24/275 - Train Accuracy: 0.7891, Validation Accuracy: 0.7885, Loss: 0.2730
# Epoch   1 Batch   30/275 - Train Accuracy: 0.8065, Validation Accuracy: 0.8145, Loss: 0.2754
# Epoch   1 Batch   36/275 - Train Accuracy: 0.8004, Validation Accuracy: 0.8035, Loss: 0.2744
# Epoch   1 Batch   42/275 - Train Accuracy: 0.8100, Validation Accuracy: 0.8233, Loss: 0.2551
# Epoch   1 Batch   48/275 - Train Accuracy: 0.8236, Validation Accuracy: 0.8175, Loss: 0.2228
# Epoch   1 Batch   54/275 - Train Accuracy: 0.8121, Validation Accuracy: 0.8346, Loss: 0.2350
# Epoch   1 Batch   60/275 - Train Accuracy: 0.8459, Validation Accuracy: 0.8378, Loss: 0.2068
# Epoch   1 Batch   66/275 - Train Accuracy: 0.8592, Validation Accuracy: 0.8401, Loss: 0.2059
# Epoch   1 Batch   72/275 - Train Accuracy: 0.8617, Validation Accuracy: 0.8433, Loss: 0.2096
# Epoch   1 Batch   78/275 - Train Accuracy: 0.8309, Validation Accuracy: 0.8446, Loss: 0.2084
# Epoch   1 Batch   84/275 - Train Accuracy: 0.8650, Validation Accuracy: 0.8498, Loss: 0.1862
# Epoch   1 Batch   90/275 - Train Accuracy: 0.8640, Validation Accuracy: 0.8580, Loss: 0.1865
# Epoch   1 Batch   96/275 - Train Accuracy: 0.8676, Validation Accuracy: 0.8516, Loss: 0.1795
# Epoch   1 Batch  102/275 - Train Accuracy: 0.8853, Validation Accuracy: 0.8560, Loss: 0.1691
# Epoch   1 Batch  108/275 - Train Accuracy: 0.8558, Validation Accuracy: 0.8633, Loss: 0.1704
# Epoch   1 Batch  114/275 - Train Accuracy: 0.8825, Validation Accuracy: 0.8601, Loss: 0.1660
# Epoch   1 Batch  120/275 - Train Accuracy: 0.8731, Validation Accuracy: 0.8845, Loss: 0.1534
# Epoch   1 Batch  126/275 - Train Accuracy: 0.8783, Validation Accuracy: 0.8800, Loss: 0.1506
# Epoch   1 Batch  132/275 - Train Accuracy: 0.8910, Validation Accuracy: 0.8869, Loss: 0.1449
# Epoch   1 Batch  138/275 - Train Accuracy: 0.8893, Validation Accuracy: 0.8822, Loss: 0.1385
# Epoch   1 Batch  144/275 - Train Accuracy: 0.8712, Validation Accuracy: 0.8712, Loss: 0.1421
# Epoch   1 Batch  150/275 - Train Accuracy: 0.8862, Validation Accuracy: 0.8868, Loss: 0.1265
# Epoch   1 Batch  156/275 - Train Accuracy: 0.8882, Validation Accuracy: 0.8906, Loss: 0.1282
# Epoch   1 Batch  162/275 - Train Accuracy: 0.9024, Validation Accuracy: 0.8989, Loss: 0.1229
# Epoch   1 Batch  168/275 - Train Accuracy: 0.9070, Validation Accuracy: 0.8921, Loss: 0.1215
# Epoch   1 Batch  174/275 - Train Accuracy: 0.8898, Validation Accuracy: 0.8963, Loss: 0.1155
# Epoch   1 Batch  180/275 - Train Accuracy: 0.8715, Validation Accuracy: 0.8854, Loss: 0.1250
# Epoch   1 Batch  186/275 - Train Accuracy: 0.8973, Validation Accuracy: 0.9005, Loss: 0.1203
# Epoch   1 Batch  192/275 - Train Accuracy: 0.9145, Validation Accuracy: 0.9078, Loss: 0.1095
# Epoch   1 Batch  198/275 - Train Accuracy: 0.9022, Validation Accuracy: 0.9026, Loss: 0.1003
# Epoch   1 Batch  204/275 - Train Accuracy: 0.9013, Validation Accuracy: 0.9041, Loss: 0.1094
# Epoch   1 Batch  210/275 - Train Accuracy: 0.9010, Validation Accuracy: 0.9092, Loss: 0.0991
# Epoch   1 Batch  216/275 - Train Accuracy: 0.9192, Validation Accuracy: 0.9086, Loss: 0.1027
# Epoch   1 Batch  222/275 - Train Accuracy: 0.8943, Validation Accuracy: 0.9135, Loss: 0.0973
# Epoch   1 Batch  228/275 - Train Accuracy: 0.9087, Validation Accuracy: 0.8987, Loss: 0.0893
# Epoch   1 Batch  234/275 - Train Accuracy: 0.9156, Validation Accuracy: 0.9203, Loss: 0.0852
# Epoch   1 Batch  240/275 - Train Accuracy: 0.9150, Validation Accuracy: 0.9049, Loss: 0.0905
# Epoch   1 Batch  246/275 - Train Accuracy: 0.9272, Validation Accuracy: 0.9119, Loss: 0.0741
# Epoch   1 Batch  252/275 - Train Accuracy: 0.9118, Validation Accuracy: 0.9152, Loss: 0.0843
# Epoch   1 Batch  258/275 - Train Accuracy: 0.9385, Validation Accuracy: 0.9215, Loss: 0.0751
# Epoch   1 Batch  264/275 - Train Accuracy: 0.9157, Validation Accuracy: 0.9107, Loss: 0.0757
# Epoch   1 Batch  270/275 - Train Accuracy: 0.9121, Validation Accuracy: 0.9176, Loss: 0.0867
# Epoch   2 Batch    6/275 - Train Accuracy: 0.9307, Validation Accuracy: 0.9234, Loss: 0.0768
# Epoch   2 Batch   12/275 - Train Accuracy: 0.9204, Validation Accuracy: 0.9237, Loss: 0.0768
# Epoch   2 Batch   18/275 - Train Accuracy: 0.9392, Validation Accuracy: 0.9253, Loss: 0.0711
# Epoch   2 Batch   24/275 - Train Accuracy: 0.9363, Validation Accuracy: 0.9227, Loss: 0.0695
# Epoch   2 Batch   30/275 - Train Accuracy: 0.9319, Validation Accuracy: 0.9227, Loss: 0.0685
# Epoch   2 Batch   36/275 - Train Accuracy: 0.9190, Validation Accuracy: 0.9172, Loss: 0.0829
# Epoch   2 Batch   42/275 - Train Accuracy: 0.9208, Validation Accuracy: 0.9166, Loss: 0.0756
# Epoch   2 Batch   48/275 - Train Accuracy: 0.9293, Validation Accuracy: 0.9271, Loss: 0.0624
# Epoch   2 Batch   54/275 - Train Accuracy: 0.9103, Validation Accuracy: 0.9162, Loss: 0.0654
# Epoch   2 Batch   60/275 - Train Accuracy: 0.9506, Validation Accuracy: 0.9286, Loss: 0.0591
# Epoch   2 Batch   66/275 - Train Accuracy: 0.9400, Validation Accuracy: 0.9251, Loss: 0.0636
# Epoch   2 Batch   72/275 - Train Accuracy: 0.9244, Validation Accuracy: 0.9409, Loss: 0.0643
# Epoch   2 Batch   78/275 - Train Accuracy: 0.9332, Validation Accuracy: 0.9299, Loss: 0.0659
# Epoch   2 Batch   84/275 - Train Accuracy: 0.9340, Validation Accuracy: 0.9181, Loss: 0.0532
# Epoch   2 Batch   90/275 - Train Accuracy: 0.9191, Validation Accuracy: 0.9281, Loss: 0.0698
# Epoch   2 Batch   96/275 - Train Accuracy: 0.9421, Validation Accuracy: 0.9275, Loss: 0.0616
# Epoch   2 Batch  102/275 - Train Accuracy: 0.9359, Validation Accuracy: 0.9283, Loss: 0.0602
# Epoch   2 Batch  108/275 - Train Accuracy: 0.9281, Validation Accuracy: 0.9395, Loss: 0.0587
# Epoch   2 Batch  114/275 - Train Accuracy: 0.9388, Validation Accuracy: 0.9295, Loss: 0.0617
# Epoch   2 Batch  120/275 - Train Accuracy: 0.9401, Validation Accuracy: 0.9305, Loss: 0.0559
# Epoch   2 Batch  126/275 - Train Accuracy: 0.9306, Validation Accuracy: 0.9257, Loss: 0.0646
# Epoch   2 Batch  132/275 - Train Accuracy: 0.9346, Validation Accuracy: 0.9342, Loss: 0.0538
# Epoch   2 Batch  138/275 - Train Accuracy: 0.9391, Validation Accuracy: 0.9315, Loss: 0.0562
# Epoch   2 Batch  144/275 - Train Accuracy: 0.9344, Validation Accuracy: 0.9319, Loss: 0.0600
# Epoch   2 Batch  150/275 - Train Accuracy: 0.9315, Validation Accuracy: 0.9443, Loss: 0.0572
# Epoch   2 Batch  156/275 - Train Accuracy: 0.9311, Validation Accuracy: 0.9281, Loss: 0.0528
# Epoch   2 Batch  162/275 - Train Accuracy: 0.9331, Validation Accuracy: 0.9335, Loss: 0.0574
# Epoch   2 Batch  168/275 - Train Accuracy: 0.9463, Validation Accuracy: 0.9332, Loss: 0.0510
# Epoch   2 Batch  174/275 - Train Accuracy: 0.9397, Validation Accuracy: 0.9222, Loss: 0.0497
# Epoch   2 Batch  180/275 - Train Accuracy: 0.9188, Validation Accuracy: 0.9395, Loss: 0.0639
# Epoch   2 Batch  186/275 - Train Accuracy: 0.9375, Validation Accuracy: 0.9403, Loss: 0.0575
# Epoch   2 Batch  192/275 - Train Accuracy: 0.9450, Validation Accuracy: 0.9367, Loss: 0.0531
# Epoch   2 Batch  198/275 - Train Accuracy: 0.9474, Validation Accuracy: 0.9478, Loss: 0.0479
# Epoch   2 Batch  204/275 - Train Accuracy: 0.9571, Validation Accuracy: 0.9351, Loss: 0.0500
# Epoch   2 Batch  210/275 - Train Accuracy: 0.9448, Validation Accuracy: 0.9425, Loss: 0.0429
# Epoch   2 Batch  216/275 - Train Accuracy: 0.9360, Validation Accuracy: 0.9433, Loss: 0.0519
# Epoch   2 Batch  222/275 - Train Accuracy: 0.9391, Validation Accuracy: 0.9425, Loss: 0.0495
# Epoch   2 Batch  228/275 - Train Accuracy: 0.9500, Validation Accuracy: 0.9333, Loss: 0.0454
# Epoch   2 Batch  234/275 - Train Accuracy: 0.9433, Validation Accuracy: 0.9405, Loss: 0.0438
# Epoch   2 Batch  240/275 - Train Accuracy: 0.9411, Validation Accuracy: 0.9393, Loss: 0.0463
# Epoch   2 Batch  246/275 - Train Accuracy: 0.9478, Validation Accuracy: 0.9404, Loss: 0.0414
# Epoch   2 Batch  252/275 - Train Accuracy: 0.9388, Validation Accuracy: 0.9372, Loss: 0.0473
# Epoch   2 Batch  258/275 - Train Accuracy: 0.9598, Validation Accuracy: 0.9445, Loss: 0.0379
# Epoch   2 Batch  264/275 - Train Accuracy: 0.9560, Validation Accuracy: 0.9472, Loss: 0.0410
# Epoch   2 Batch  270/275 - Train Accuracy: 0.9307, Validation Accuracy: 0.9524, Loss: 0.0484
# Epoch   3 Batch    6/275 - Train Accuracy: 0.9529, Validation Accuracy: 0.9475, Loss: 0.0452
# Epoch   3 Batch   12/275 - Train Accuracy: 0.9485, Validation Accuracy: 0.9446, Loss: 0.0479
# Epoch   3 Batch   18/275 - Train Accuracy: 0.9558, Validation Accuracy: 0.9495, Loss: 0.0422
# Epoch   3 Batch   24/275 - Train Accuracy: 0.9461, Validation Accuracy: 0.9495, Loss: 0.0413
# Epoch   3 Batch   30/275 - Train Accuracy: 0.9603, Validation Accuracy: 0.9421, Loss: 0.0449
# Epoch   3 Batch   36/275 - Train Accuracy: 0.9441, Validation Accuracy: 0.9316, Loss: 0.0524
# Epoch   3 Batch   42/275 - Train Accuracy: 0.9439, Validation Accuracy: 0.9344, Loss: 0.0426
# Epoch   3 Batch   48/275 - Train Accuracy: 0.9527, Validation Accuracy: 0.9513, Loss: 0.0371
# Epoch   3 Batch   54/275 - Train Accuracy: 0.9449, Validation Accuracy: 0.9395, Loss: 0.0397
# Epoch   3 Batch   60/275 - Train Accuracy: 0.9606, Validation Accuracy: 0.9486, Loss: 0.0352
# Epoch   3 Batch   66/275 - Train Accuracy: 0.9603, Validation Accuracy: 0.9419, Loss: 0.0358
# Epoch   3 Batch   72/275 - Train Accuracy: 0.9516, Validation Accuracy: 0.9454, Loss: 0.0442
# Epoch   3 Batch   78/275 - Train Accuracy: 0.9461, Validation Accuracy: 0.9480, Loss: 0.0398
# Epoch   3 Batch   84/275 - Train Accuracy: 0.9605, Validation Accuracy: 0.9365, Loss: 0.0345
# Epoch   3 Batch   90/275 - Train Accuracy: 0.9394, Validation Accuracy: 0.9405, Loss: 0.0421
# Epoch   3 Batch   96/275 - Train Accuracy: 0.9544, Validation Accuracy: 0.9482, Loss: 0.0416
# Epoch   3 Batch  102/275 - Train Accuracy: 0.9593, Validation Accuracy: 0.9537, Loss: 0.0426
# Epoch   3 Batch  108/275 - Train Accuracy: 0.9458, Validation Accuracy: 0.9465, Loss: 0.0363
# Epoch   3 Batch  114/275 - Train Accuracy: 0.9523, Validation Accuracy: 0.9419, Loss: 0.0390
# Epoch   3 Batch  120/275 - Train Accuracy: 0.9530, Validation Accuracy: 0.9501, Loss: 0.0337
# Epoch   3 Batch  126/275 - Train Accuracy: 0.9532, Validation Accuracy: 0.9530, Loss: 0.0413
# Epoch   3 Batch  132/275 - Train Accuracy: 0.9592, Validation Accuracy: 0.9596, Loss: 0.0394
# Epoch   3 Batch  138/275 - Train Accuracy: 0.9626, Validation Accuracy: 0.9564, Loss: 0.0342
# Epoch   3 Batch  144/275 - Train Accuracy: 0.9496, Validation Accuracy: 0.9532, Loss: 0.0420
# Epoch   3 Batch  150/275 - Train Accuracy: 0.9505, Validation Accuracy: 0.9451, Loss: 0.0368
# Epoch   3 Batch  156/275 - Train Accuracy: 0.9595, Validation Accuracy: 0.9541, Loss: 0.0379
# Epoch   3 Batch  162/275 - Train Accuracy: 0.9502, Validation Accuracy: 0.9565, Loss: 0.0414
# Epoch   3 Batch  168/275 - Train Accuracy: 0.9549, Validation Accuracy: 0.9518, Loss: 0.0377
# Epoch   3 Batch  174/275 - Train Accuracy: 0.9497, Validation Accuracy: 0.9546, Loss: 0.0387
# Epoch   3 Batch  180/275 - Train Accuracy: 0.9438, Validation Accuracy: 0.9588, Loss: 0.0471
# Epoch   3 Batch  186/275 - Train Accuracy: 0.9495, Validation Accuracy: 0.9551, Loss: 0.0412
# Epoch   3 Batch  192/275 - Train Accuracy: 0.9532, Validation Accuracy: 0.9460, Loss: 0.0378
# Epoch   3 Batch  198/275 - Train Accuracy: 0.9580, Validation Accuracy: 0.9542, Loss: 0.0340
# Epoch   3 Batch  204/275 - Train Accuracy: 0.9546, Validation Accuracy: 0.9608, Loss: 0.0390
# Epoch   3 Batch  210/275 - Train Accuracy: 0.9645, Validation Accuracy: 0.9493, Loss: 0.0303
# Epoch   3 Batch  216/275 - Train Accuracy: 0.9514, Validation Accuracy: 0.9454, Loss: 0.0354
# Epoch   3 Batch  222/275 - Train Accuracy: 0.9478, Validation Accuracy: 0.9485, Loss: 0.0337
# Epoch   3 Batch  228/275 - Train Accuracy: 0.9579, Validation Accuracy: 0.9552, Loss: 0.0298
# Epoch   3 Batch  234/275 - Train Accuracy: 0.9629, Validation Accuracy: 0.9676, Loss: 0.0305
# Epoch   3 Batch  240/275 - Train Accuracy: 0.9556, Validation Accuracy: 0.9560, Loss: 0.0356
# Epoch   3 Batch  246/275 - Train Accuracy: 0.9533, Validation Accuracy: 0.9525, Loss: 0.0296
# Epoch   3 Batch  252/275 - Train Accuracy: 0.9538, Validation Accuracy: 0.9535, Loss: 0.0361
# Epoch   3 Batch  258/275 - Train Accuracy: 0.9620, Validation Accuracy: 0.9401, Loss: 0.0288
# Epoch   3 Batch  264/275 - Train Accuracy: 0.9603, Validation Accuracy: 0.9531, Loss: 0.0328
# Epoch   3 Batch  270/275 - Train Accuracy: 0.9551, Validation Accuracy: 0.9570, Loss: 0.0361
# Epoch   4 Batch    6/275 - Train Accuracy: 0.9606, Validation Accuracy: 0.9662, Loss: 0.0369
# Epoch   4 Batch   12/275 - Train Accuracy: 0.9507, Validation Accuracy: 0.9655, Loss: 0.0386
# Epoch   4 Batch   18/275 - Train Accuracy: 0.9648, Validation Accuracy: 0.9638, Loss: 0.0337
# Epoch   4 Batch   24/275 - Train Accuracy: 0.9534, Validation Accuracy: 0.9568, Loss: 0.0335
# Epoch   4 Batch   30/275 - Train Accuracy: 0.9597, Validation Accuracy: 0.9507, Loss: 0.0363
# Epoch   4 Batch   36/275 - Train Accuracy: 0.9531, Validation Accuracy: 0.9576, Loss: 0.0485
# Epoch   4 Batch   42/275 - Train Accuracy: 0.9493, Validation Accuracy: 0.9515, Loss: 0.0347
# Epoch   4 Batch   48/275 - Train Accuracy: 0.9625, Validation Accuracy: 0.9621, Loss: 0.0255
# Epoch   4 Batch   54/275 - Train Accuracy: 0.9575, Validation Accuracy: 0.9551, Loss: 0.0309
# Epoch   4 Batch   60/275 - Train Accuracy: 0.9673, Validation Accuracy: 0.9562, Loss: 0.0270
# Epoch   4 Batch   66/275 - Train Accuracy: 0.9668, Validation Accuracy: 0.9615, Loss: 0.0275
# Epoch   4 Batch   72/275 - Train Accuracy: 0.9635, Validation Accuracy: 0.9570, Loss: 0.0350
# Epoch   4 Batch   78/275 - Train Accuracy: 0.9590, Validation Accuracy: 0.9470, Loss: 0.0311
# Epoch   4 Batch   84/275 - Train Accuracy: 0.9708, Validation Accuracy: 0.9445, Loss: 0.0275
# Epoch   4 Batch   90/275 - Train Accuracy: 0.9560, Validation Accuracy: 0.9528, Loss: 0.0354
# Epoch   4 Batch   96/275 - Train Accuracy: 0.9630, Validation Accuracy: 0.9632, Loss: 0.0336
# Epoch   4 Batch  102/275 - Train Accuracy: 0.9619, Validation Accuracy: 0.9587, Loss: 0.0335
# Epoch   4 Batch  108/275 - Train Accuracy: 0.9651, Validation Accuracy: 0.9604, Loss: 0.0296
# Epoch   4 Batch  114/275 - Train Accuracy: 0.9666, Validation Accuracy: 0.9550, Loss: 0.0314
# Epoch   4 Batch  120/275 - Train Accuracy: 0.9669, Validation Accuracy: 0.9591, Loss: 0.0277
# Epoch   4 Batch  126/275 - Train Accuracy: 0.9600, Validation Accuracy: 0.9674, Loss: 0.0301
# Epoch   4 Batch  132/275 - Train Accuracy: 0.9656, Validation Accuracy: 0.9663, Loss: 0.0291
# Epoch   4 Batch  138/275 - Train Accuracy: 0.9632, Validation Accuracy: 0.9629, Loss: 0.0283
# Epoch   4 Batch  144/275 - Train Accuracy: 0.9621, Validation Accuracy: 0.9587, Loss: 0.0364
# Epoch   4 Batch  150/275 - Train Accuracy: 0.9632, Validation Accuracy: 0.9675, Loss: 0.0298
# Epoch   4 Batch  156/275 - Train Accuracy: 0.9691, Validation Accuracy: 0.9657, Loss: 0.0287
# Epoch   4 Batch  162/275 - Train Accuracy: 0.9576, Validation Accuracy: 0.9628, Loss: 0.0279
# Epoch   4 Batch  168/275 - Train Accuracy: 0.9682, Validation Accuracy: 0.9595, Loss: 0.0303
# Epoch   4 Batch  174/275 - Train Accuracy: 0.9589, Validation Accuracy: 0.9650, Loss: 0.0293
# Epoch   4 Batch  180/275 - Train Accuracy: 0.9472, Validation Accuracy: 0.9550, Loss: 0.0405
# Epoch   4 Batch  186/275 - Train Accuracy: 0.9458, Validation Accuracy: 0.9557, Loss: 0.0351
# Epoch   4 Batch  192/275 - Train Accuracy: 0.9579, Validation Accuracy: 0.9575, Loss: 0.0310
# Epoch   4 Batch  198/275 - Train Accuracy: 0.9649, Validation Accuracy: 0.9568, Loss: 0.0290
# Epoch   4 Batch  204/275 - Train Accuracy: 0.9704, Validation Accuracy: 0.9682, Loss: 0.0318
# Epoch   4 Batch  210/275 - Train Accuracy: 0.9740, Validation Accuracy: 0.9606, Loss: 0.0241
# Epoch   4 Batch  216/275 - Train Accuracy: 0.9679, Validation Accuracy: 0.9511, Loss: 0.0309
# Epoch   4 Batch  222/275 - Train Accuracy: 0.9612, Validation Accuracy: 0.9595, Loss: 0.0313
# Epoch   4 Batch  228/275 - Train Accuracy: 0.9679, Validation Accuracy: 0.9618, Loss: 0.0256
# Epoch   4 Batch  234/275 - Train Accuracy: 0.9696, Validation Accuracy: 0.9588, Loss: 0.0213
# Epoch   4 Batch  240/275 - Train Accuracy: 0.9605, Validation Accuracy: 0.9578, Loss: 0.0258
# Epoch   4 Batch  246/275 - Train Accuracy: 0.9643, Validation Accuracy: 0.9560, Loss: 0.0219
# Epoch   4 Batch  252/275 - Train Accuracy: 0.9556, Validation Accuracy: 0.9591, Loss: 0.0311
# Epoch   4 Batch  258/275 - Train Accuracy: 0.9708, Validation Accuracy: 0.9587, Loss: 0.0234
# Epoch   4 Batch  264/275 - Train Accuracy: 0.9648, Validation Accuracy: 0.9519, Loss: 0.0259
# Epoch   4 Batch  270/275 - Train Accuracy: 0.9538, Validation Accuracy: 0.9647, Loss: 0.0337
# Epoch   5 Batch    6/275 - Train Accuracy: 0.9636, Validation Accuracy: 0.9613, Loss: 0.0289
# Epoch   5 Batch   12/275 - Train Accuracy: 0.9637, Validation Accuracy: 0.9660, Loss: 0.0315
# Epoch   5 Batch   18/275 - Train Accuracy: 0.9620, Validation Accuracy: 0.9574, Loss: 0.0308
# Epoch   5 Batch   24/275 - Train Accuracy: 0.9629, Validation Accuracy: 0.9635, Loss: 0.0266
# Epoch   5 Batch   30/275 - Train Accuracy: 0.9659, Validation Accuracy: 0.9597, Loss: 0.0278
# Epoch   5 Batch   36/275 - Train Accuracy: 0.9696, Validation Accuracy: 0.9575, Loss: 0.0359
# Epoch   5 Batch   42/275 - Train Accuracy: 0.9627, Validation Accuracy: 0.9659, Loss: 0.0309
# Epoch   5 Batch   48/275 - Train Accuracy: 0.9661, Validation Accuracy: 0.9645, Loss: 0.0252
# Epoch   5 Batch   54/275 - Train Accuracy: 0.9625, Validation Accuracy: 0.9598, Loss: 0.0269
# Epoch   5 Batch   60/275 - Train Accuracy: 0.9772, Validation Accuracy: 0.9612, Loss: 0.0228
# Epoch   5 Batch   66/275 - Train Accuracy: 0.9750, Validation Accuracy: 0.9646, Loss: 0.0208
# Epoch   5 Batch   72/275 - Train Accuracy: 0.9639, Validation Accuracy: 0.9589, Loss: 0.0302
# Epoch   5 Batch   78/275 - Train Accuracy: 0.9750, Validation Accuracy: 0.9583, Loss: 0.0257
# Epoch   5 Batch   84/275 - Train Accuracy: 0.9699, Validation Accuracy: 0.9629, Loss: 0.0220
# Epoch   5 Batch   90/275 - Train Accuracy: 0.9513, Validation Accuracy: 0.9504, Loss: 0.0298
# Epoch   5 Batch   96/275 - Train Accuracy: 0.9674, Validation Accuracy: 0.9596, Loss: 0.0264
# Epoch   5 Batch  102/275 - Train Accuracy: 0.9681, Validation Accuracy: 0.9588, Loss: 0.0287
# Epoch   5 Batch  108/275 - Train Accuracy: 0.9725, Validation Accuracy: 0.9644, Loss: 0.0233
# Epoch   5 Batch  114/275 - Train Accuracy: 0.9715, Validation Accuracy: 0.9635, Loss: 0.0291
# Epoch   5 Batch  120/275 - Train Accuracy: 0.9711, Validation Accuracy: 0.9642, Loss: 0.0245
# Epoch   5 Batch  126/275 - Train Accuracy: 0.9694, Validation Accuracy: 0.9630, Loss: 0.0264
# Epoch   5 Batch  132/275 - Train Accuracy: 0.9613, Validation Accuracy: 0.9632, Loss: 0.0256
# Epoch   5 Batch  138/275 - Train Accuracy: 0.9733, Validation Accuracy: 0.9717, Loss: 0.0240
# Epoch   5 Batch  144/275 - Train Accuracy: 0.9704, Validation Accuracy: 0.9639, Loss: 0.0292
# Epoch   5 Batch  150/275 - Train Accuracy: 0.9625, Validation Accuracy: 0.9675, Loss: 0.0256
# Epoch   5 Batch  156/275 - Train Accuracy: 0.9779, Validation Accuracy: 0.9708, Loss: 0.0241
# Epoch   5 Batch  162/275 - Train Accuracy: 0.9556, Validation Accuracy: 0.9717, Loss: 0.0275
# Epoch   5 Batch  168/275 - Train Accuracy: 0.9683, Validation Accuracy: 0.9631, Loss: 0.0247
# Epoch   5 Batch  174/275 - Train Accuracy: 0.9685, Validation Accuracy: 0.9681, Loss: 0.0261
# Epoch   5 Batch  180/275 - Train Accuracy: 0.9550, Validation Accuracy: 0.9660, Loss: 0.0341
# Epoch   5 Batch  186/275 - Train Accuracy: 0.9509, Validation Accuracy: 0.9694, Loss: 0.0301
# Epoch   5 Batch  192/275 - Train Accuracy: 0.9646, Validation Accuracy: 0.9670, Loss: 0.0252
# Epoch   5 Batch  198/275 - Train Accuracy: 0.9646, Validation Accuracy: 0.9609, Loss: 0.0250
# Epoch   5 Batch  204/275 - Train Accuracy: 0.9730, Validation Accuracy: 0.9596, Loss: 0.0244
# Epoch   5 Batch  210/275 - Train Accuracy: 0.9768, Validation Accuracy: 0.9637, Loss: 0.0228
# Epoch   5 Batch  216/275 - Train Accuracy: 0.9679, Validation Accuracy: 0.9586, Loss: 0.0288
# Epoch   5 Batch  222/275 - Train Accuracy: 0.9716, Validation Accuracy: 0.9578, Loss: 0.0244
# Epoch   5 Batch  228/275 - Train Accuracy: 0.9690, Validation Accuracy: 0.9597, Loss: 0.0216
# Epoch   5 Batch  234/275 - Train Accuracy: 0.9675, Validation Accuracy: 0.9720, Loss: 0.0232
# Epoch   5 Batch  240/275 - Train Accuracy: 0.9700, Validation Accuracy: 0.9665, Loss: 0.0231
# Epoch   5 Batch  246/275 - Train Accuracy: 0.9739, Validation Accuracy: 0.9650, Loss: 0.0213
# Epoch   5 Batch  252/275 - Train Accuracy: 0.9700, Validation Accuracy: 0.9658, Loss: 0.0253
# Epoch   5 Batch  258/275 - Train Accuracy: 0.9751, Validation Accuracy: 0.9665, Loss: 0.0202
# Epoch   5 Batch  264/275 - Train Accuracy: 0.9735, Validation Accuracy: 0.9706, Loss: 0.0228
# Epoch   5 Batch  270/275 - Train Accuracy: 0.9547, Validation Accuracy: 0.9612, Loss: 0.0305
# Epoch   6 Batch    6/275 - Train Accuracy: 0.9676, Validation Accuracy: 0.9690, Loss: 0.0266
# Epoch   6 Batch   12/275 - Train Accuracy: 0.9628, Validation Accuracy: 0.9609, Loss: 0.0310
# Epoch   6 Batch   18/275 - Train Accuracy: 0.9615, Validation Accuracy: 0.9690, Loss: 0.0275
# Epoch   6 Batch   24/275 - Train Accuracy: 0.9626, Validation Accuracy: 0.9633, Loss: 0.0246
# Epoch   6 Batch   30/275 - Train Accuracy: 0.9731, Validation Accuracy: 0.9663, Loss: 0.0251
# Epoch   6 Batch   36/275 - Train Accuracy: 0.9669, Validation Accuracy: 0.9640, Loss: 0.0303
# Epoch   6 Batch   42/275 - Train Accuracy: 0.9635, Validation Accuracy: 0.9631, Loss: 0.0304
# Epoch   6 Batch   48/275 - Train Accuracy: 0.9710, Validation Accuracy: 0.9602, Loss: 0.0214
# Epoch   6 Batch   54/275 - Train Accuracy: 0.9627, Validation Accuracy: 0.9621, Loss: 0.0235
# Epoch   6 Batch   60/275 - Train Accuracy: 0.9752, Validation Accuracy: 0.9661, Loss: 0.0199
# Epoch   6 Batch   66/275 - Train Accuracy: 0.9710, Validation Accuracy: 0.9695, Loss: 0.0239
# Epoch   6 Batch   72/275 - Train Accuracy: 0.9590, Validation Accuracy: 0.9616, Loss: 0.0273
# Epoch   6 Batch   78/275 - Train Accuracy: 0.9613, Validation Accuracy: 0.9699, Loss: 0.0255
# Epoch   6 Batch   84/275 - Train Accuracy: 0.9785, Validation Accuracy: 0.9671, Loss: 0.0192
# Epoch   6 Batch   90/275 - Train Accuracy: 0.9692, Validation Accuracy: 0.9685, Loss: 0.0248
# Epoch   6 Batch   96/275 - Train Accuracy: 0.9690, Validation Accuracy: 0.9710, Loss: 0.0273
# Epoch   6 Batch  102/275 - Train Accuracy: 0.9762, Validation Accuracy: 0.9650, Loss: 0.0280
# Epoch   6 Batch  108/275 - Train Accuracy: 0.9710, Validation Accuracy: 0.9712, Loss: 0.0226
# Epoch   6 Batch  114/275 - Train Accuracy: 0.9776, Validation Accuracy: 0.9657, Loss: 0.0265
# Epoch   6 Batch  120/275 - Train Accuracy: 0.9715, Validation Accuracy: 0.9683, Loss: 0.0207
# Epoch   6 Batch  126/275 - Train Accuracy: 0.9662, Validation Accuracy: 0.9709, Loss: 0.0241
# Epoch   6 Batch  132/275 - Train Accuracy: 0.9681, Validation Accuracy: 0.9692, Loss: 0.0247
# Epoch   6 Batch  138/275 - Train Accuracy: 0.9748, Validation Accuracy: 0.9683, Loss: 0.0209
# Epoch   6 Batch  144/275 - Train Accuracy: 0.9707, Validation Accuracy: 0.9666, Loss: 0.0266
# Epoch   6 Batch  150/275 - Train Accuracy: 0.9633, Validation Accuracy: 0.9604, Loss: 0.0236
# Epoch   6 Batch  156/275 - Train Accuracy: 0.9776, Validation Accuracy: 0.9703, Loss: 0.0213
# Epoch   6 Batch  162/275 - Train Accuracy: 0.9658, Validation Accuracy: 0.9692, Loss: 0.0254
# Epoch   6 Batch  168/275 - Train Accuracy: 0.9716, Validation Accuracy: 0.9686, Loss: 0.0203
# Epoch   6 Batch  174/275 - Train Accuracy: 0.9680, Validation Accuracy: 0.9677, Loss: 0.0233
# Epoch   6 Batch  180/275 - Train Accuracy: 0.9653, Validation Accuracy: 0.9696, Loss: 0.0355
# Epoch   6 Batch  186/275 - Train Accuracy: 0.9598, Validation Accuracy: 0.9721, Loss: 0.0315
# Epoch   6 Batch  192/275 - Train Accuracy: 0.9588, Validation Accuracy: 0.9700, Loss: 0.0272
# Epoch   6 Batch  198/275 - Train Accuracy: 0.9676, Validation Accuracy: 0.9691, Loss: 0.0212
# Epoch   6 Batch  204/275 - Train Accuracy: 0.9769, Validation Accuracy: 0.9725, Loss: 0.0223
# Epoch   6 Batch  210/275 - Train Accuracy: 0.9816, Validation Accuracy: 0.9647, Loss: 0.0186
# Epoch   6 Batch  216/275 - Train Accuracy: 0.9711, Validation Accuracy: 0.9727, Loss: 0.0235
# Epoch   6 Batch  222/275 - Train Accuracy: 0.9698, Validation Accuracy: 0.9671, Loss: 0.0223
# Epoch   6 Batch  228/275 - Train Accuracy: 0.9708, Validation Accuracy: 0.9670, Loss: 0.0205
# Epoch   6 Batch  234/275 - Train Accuracy: 0.9827, Validation Accuracy: 0.9670, Loss: 0.0198
# Epoch   6 Batch  240/275 - Train Accuracy: 0.9737, Validation Accuracy: 0.9746, Loss: 0.0246
# Epoch   6 Batch  246/275 - Train Accuracy: 0.9701, Validation Accuracy: 0.9692, Loss: 0.0216
# Epoch   6 Batch  252/275 - Train Accuracy: 0.9644, Validation Accuracy: 0.9561, Loss: 0.0272
# Epoch   6 Batch  258/275 - Train Accuracy: 0.9744, Validation Accuracy: 0.9621, Loss: 0.0221
# Epoch   6 Batch  264/275 - Train Accuracy: 0.9672, Validation Accuracy: 0.9509, Loss: 0.0233
# Epoch   6 Batch  270/275 - Train Accuracy: 0.9628, Validation Accuracy: 0.9629, Loss: 0.0297
# Epoch   7 Batch    6/275 - Train Accuracy: 0.9767, Validation Accuracy: 0.9583, Loss: 0.0266
# Epoch   7 Batch   12/275 - Train Accuracy: 0.9690, Validation Accuracy: 0.9683, Loss: 0.0275
# Epoch   7 Batch   18/275 - Train Accuracy: 0.9651, Validation Accuracy: 0.9553, Loss: 0.0250
# Epoch   7 Batch   24/275 - Train Accuracy: 0.9632, Validation Accuracy: 0.9655, Loss: 0.0268
# Epoch   7 Batch   30/275 - Train Accuracy: 0.9663, Validation Accuracy: 0.9653, Loss: 0.0256
# Epoch   7 Batch   36/275 - Train Accuracy: 0.9709, Validation Accuracy: 0.9645, Loss: 0.0337
# Epoch   7 Batch   42/275 - Train Accuracy: 0.9685, Validation Accuracy: 0.9667, Loss: 0.0277
# Epoch   7 Batch   48/275 - Train Accuracy: 0.9738, Validation Accuracy: 0.9691, Loss: 0.0200
# Epoch   7 Batch   54/275 - Train Accuracy: 0.9697, Validation Accuracy: 0.9628, Loss: 0.0214
# Epoch   7 Batch   60/275 - Train Accuracy: 0.9811, Validation Accuracy: 0.9654, Loss: 0.0226
# Epoch   7 Batch   66/275 - Train Accuracy: 0.9740, Validation Accuracy: 0.9665, Loss: 0.0197
# Epoch   7 Batch   72/275 - Train Accuracy: 0.9653, Validation Accuracy: 0.9544, Loss: 0.0262
# Epoch   7 Batch   78/275 - Train Accuracy: 0.9711, Validation Accuracy: 0.9655, Loss: 0.0253
# Epoch   7 Batch   84/275 - Train Accuracy: 0.9763, Validation Accuracy: 0.9716, Loss: 0.0183
# Epoch   7 Batch   90/275 - Train Accuracy: 0.9701, Validation Accuracy: 0.9726, Loss: 0.0241
# Epoch   7 Batch   96/275 - Train Accuracy: 0.9694, Validation Accuracy: 0.9747, Loss: 0.0247
# Epoch   7 Batch  102/275 - Train Accuracy: 0.9777, Validation Accuracy: 0.9698, Loss: 0.0232
# Epoch   7 Batch  108/275 - Train Accuracy: 0.9718, Validation Accuracy: 0.9724, Loss: 0.0198
# Epoch   7 Batch  114/275 - Train Accuracy: 0.9717, Validation Accuracy: 0.9667, Loss: 0.0231
# Epoch   7 Batch  120/275 - Train Accuracy: 0.9705, Validation Accuracy: 0.9688, Loss: 0.0219
# Epoch   7 Batch  126/275 - Train Accuracy: 0.9627, Validation Accuracy: 0.9726, Loss: 0.0226
# Epoch   7 Batch  132/275 - Train Accuracy: 0.9715, Validation Accuracy: 0.9680, Loss: 0.0220
# Epoch   7 Batch  138/275 - Train Accuracy: 0.9712, Validation Accuracy: 0.9755, Loss: 0.0215
# Epoch   7 Batch  144/275 - Train Accuracy: 0.9755, Validation Accuracy: 0.9707, Loss: 0.0232
# Epoch   7 Batch  150/275 - Train Accuracy: 0.9687, Validation Accuracy: 0.9633, Loss: 0.0212
# Epoch   7 Batch  156/275 - Train Accuracy: 0.9779, Validation Accuracy: 0.9683, Loss: 0.0209
# Epoch   7 Batch  162/275 - Train Accuracy: 0.9663, Validation Accuracy: 0.9736, Loss: 0.0250
# Epoch   7 Batch  168/275 - Train Accuracy: 0.9777, Validation Accuracy: 0.9716, Loss: 0.0195
# Epoch   7 Batch  174/275 - Train Accuracy: 0.9644, Validation Accuracy: 0.9675, Loss: 0.0222
# Epoch   7 Batch  180/275 - Train Accuracy: 0.9570, Validation Accuracy: 0.9660, Loss: 0.0291
# Epoch   7 Batch  186/275 - Train Accuracy: 0.9597, Validation Accuracy: 0.9665, Loss: 0.0260
# Epoch   7 Batch  192/275 - Train Accuracy: 0.9714, Validation Accuracy: 0.9625, Loss: 0.0240
# Epoch   7 Batch  198/275 - Train Accuracy: 0.9640, Validation Accuracy: 0.9669, Loss: 0.0217
# Epoch   7 Batch  204/275 - Train Accuracy: 0.9774, Validation Accuracy: 0.9659, Loss: 0.0210
# Epoch   7 Batch  210/275 - Train Accuracy: 0.9843, Validation Accuracy: 0.9647, Loss: 0.0167
# Epoch   7 Batch  216/275 - Train Accuracy: 0.9711, Validation Accuracy: 0.9622, Loss: 0.0216
# Epoch   7 Batch  222/275 - Train Accuracy: 0.9653, Validation Accuracy: 0.9642, Loss: 0.0213
# Epoch   7 Batch  228/275 - Train Accuracy: 0.9711, Validation Accuracy: 0.9676, Loss: 0.0185
# Epoch   7 Batch  234/275 - Train Accuracy: 0.9723, Validation Accuracy: 0.9727, Loss: 0.0203
# Epoch   7 Batch  240/275 - Train Accuracy: 0.9734, Validation Accuracy: 0.9697, Loss: 0.0203
# Epoch   7 Batch  246/275 - Train Accuracy: 0.9785, Validation Accuracy: 0.9635, Loss: 0.0157
# Epoch   7 Batch  252/275 - Train Accuracy: 0.9720, Validation Accuracy: 0.9648, Loss: 0.0245
# Epoch   7 Batch  258/275 - Train Accuracy: 0.9749, Validation Accuracy: 0.9660, Loss: 0.0204
# Epoch   7 Batch  264/275 - Train Accuracy: 0.9774, Validation Accuracy: 0.9657, Loss: 0.0209
# Epoch   7 Batch  270/275 - Train Accuracy: 0.9595, Validation Accuracy: 0.9655, Loss: 0.0263
# Epoch   8 Batch    6/275 - Train Accuracy: 0.9762, Validation Accuracy: 0.9678, Loss: 0.0236
# Epoch   8 Batch   12/275 - Train Accuracy: 0.9747, Validation Accuracy: 0.9725, Loss: 0.0263
# Epoch   8 Batch   18/275 - Train Accuracy: 0.9745, Validation Accuracy: 0.9601, Loss: 0.0244
# Epoch   8 Batch   24/275 - Train Accuracy: 0.9688, Validation Accuracy: 0.9708, Loss: 0.0194
# Epoch   8 Batch   30/275 - Train Accuracy: 0.9772, Validation Accuracy: 0.9670, Loss: 0.0198
# Epoch   8 Batch   36/275 - Train Accuracy: 0.9710, Validation Accuracy: 0.9609, Loss: 0.0300
# Epoch   8 Batch   42/275 - Train Accuracy: 0.9670, Validation Accuracy: 0.9613, Loss: 0.0237
# Epoch   8 Batch   48/275 - Train Accuracy: 0.9757, Validation Accuracy: 0.9707, Loss: 0.0182
# Epoch   8 Batch   54/275 - Train Accuracy: 0.9782, Validation Accuracy: 0.9624, Loss: 0.0201
# Epoch   8 Batch   60/275 - Train Accuracy: 0.9766, Validation Accuracy: 0.9589, Loss: 0.0219
# Epoch   8 Batch   66/275 - Train Accuracy: 0.9748, Validation Accuracy: 0.9641, Loss: 0.0179
# Epoch   8 Batch   72/275 - Train Accuracy: 0.9644, Validation Accuracy: 0.9665, Loss: 0.0246
# Epoch   8 Batch   78/275 - Train Accuracy: 0.9704, Validation Accuracy: 0.9635, Loss: 0.0223
# Epoch   8 Batch   84/275 - Train Accuracy: 0.9790, Validation Accuracy: 0.9624, Loss: 0.0187
# Epoch   8 Batch   90/275 - Train Accuracy: 0.9706, Validation Accuracy: 0.9649, Loss: 0.0216
# Epoch   8 Batch   96/275 - Train Accuracy: 0.9721, Validation Accuracy: 0.9681, Loss: 0.0228
# Epoch   8 Batch  102/275 - Train Accuracy: 0.9763, Validation Accuracy: 0.9674, Loss: 0.0221
# Epoch   8 Batch  108/275 - Train Accuracy: 0.9795, Validation Accuracy: 0.9707, Loss: 0.0177
# Epoch   8 Batch  114/275 - Train Accuracy: 0.9736, Validation Accuracy: 0.9668, Loss: 0.0246
# Epoch   8 Batch  120/275 - Train Accuracy: 0.9732, Validation Accuracy: 0.9737, Loss: 0.0222
# Epoch   8 Batch  126/275 - Train Accuracy: 0.9604, Validation Accuracy: 0.9754, Loss: 0.0257
# Epoch   8 Batch  132/275 - Train Accuracy: 0.9768, Validation Accuracy: 0.9690, Loss: 0.0190
# Epoch   8 Batch  138/275 - Train Accuracy: 0.9781, Validation Accuracy: 0.9706, Loss: 0.0187
# Epoch   8 Batch  144/275 - Train Accuracy: 0.9781, Validation Accuracy: 0.9698, Loss: 0.0225
# Epoch   8 Batch  150/275 - Train Accuracy: 0.9742, Validation Accuracy: 0.9670, Loss: 0.0218
# Epoch   8 Batch  156/275 - Train Accuracy: 0.9843, Validation Accuracy: 0.9662, Loss: 0.0186
# Epoch   8 Batch  162/275 - Train Accuracy: 0.9670, Validation Accuracy: 0.9681, Loss: 0.0258
# Epoch   8 Batch  168/275 - Train Accuracy: 0.9781, Validation Accuracy: 0.9655, Loss: 0.0209
# Epoch   8 Batch  174/275 - Train Accuracy: 0.9730, Validation Accuracy: 0.9707, Loss: 0.0178
# Epoch   8 Batch  180/275 - Train Accuracy: 0.9662, Validation Accuracy: 0.9684, Loss: 0.0331
# Epoch   8 Batch  186/275 - Train Accuracy: 0.9630, Validation Accuracy: 0.9674, Loss: 0.0247
# Epoch   8 Batch  192/275 - Train Accuracy: 0.9701, Validation Accuracy: 0.9674, Loss: 0.0237
# Epoch   8 Batch  198/275 - Train Accuracy: 0.9700, Validation Accuracy: 0.9672, Loss: 0.0180
# Epoch   8 Batch  204/275 - Train Accuracy: 0.9869, Validation Accuracy: 0.9695, Loss: 0.0178
# Epoch   8 Batch  210/275 - Train Accuracy: 0.9793, Validation Accuracy: 0.9683, Loss: 0.0168
# Epoch   8 Batch  216/275 - Train Accuracy: 0.9732, Validation Accuracy: 0.9628, Loss: 0.0225
# Epoch   8 Batch  222/275 - Train Accuracy: 0.9778, Validation Accuracy: 0.9715, Loss: 0.0204
# Epoch   8 Batch  228/275 - Train Accuracy: 0.9761, Validation Accuracy: 0.9704, Loss: 0.0192
# Epoch   8 Batch  234/275 - Train Accuracy: 0.9830, Validation Accuracy: 0.9683, Loss: 0.0190
# Epoch   8 Batch  240/275 - Train Accuracy: 0.9767, Validation Accuracy: 0.9725, Loss: 0.0226
# Epoch   8 Batch  246/275 - Train Accuracy: 0.9770, Validation Accuracy: 0.9662, Loss: 0.0183
# Epoch   8 Batch  252/275 - Train Accuracy: 0.9681, Validation Accuracy: 0.9700, Loss: 0.0215
# Epoch   8 Batch  258/275 - Train Accuracy: 0.9736, Validation Accuracy: 0.9733, Loss: 0.0187
# Epoch   8 Batch  264/275 - Train Accuracy: 0.9779, Validation Accuracy: 0.9754, Loss: 0.0172
# Epoch   8 Batch  270/275 - Train Accuracy: 0.9612, Validation Accuracy: 0.9694, Loss: 0.0255
# Epoch   9 Batch    6/275 - Train Accuracy: 0.9782, Validation Accuracy: 0.9695, Loss: 0.0217
# Epoch   9 Batch   12/275 - Train Accuracy: 0.9734, Validation Accuracy: 0.9654, Loss: 0.0242
# Epoch   9 Batch   18/275 - Train Accuracy: 0.9709, Validation Accuracy: 0.9737, Loss: 0.0230
# Epoch   9 Batch   24/275 - Train Accuracy: 0.9688, Validation Accuracy: 0.9665, Loss: 0.0240
# Epoch   9 Batch   30/275 - Train Accuracy: 0.9706, Validation Accuracy: 0.9726, Loss: 0.0219
# Epoch   9 Batch   36/275 - Train Accuracy: 0.9735, Validation Accuracy: 0.9709, Loss: 0.0311
# Epoch   9 Batch   42/275 - Train Accuracy: 0.9678, Validation Accuracy: 0.9677, Loss: 0.0235
# Epoch   9 Batch   48/275 - Train Accuracy: 0.9752, Validation Accuracy: 0.9700, Loss: 0.0207
# Epoch   9 Batch   54/275 - Train Accuracy: 0.9670, Validation Accuracy: 0.9678, Loss: 0.0217
# Epoch   9 Batch   60/275 - Train Accuracy: 0.9778, Validation Accuracy: 0.9725, Loss: 0.0189
# Epoch   9 Batch   66/275 - Train Accuracy: 0.9807, Validation Accuracy: 0.9723, Loss: 0.0193
# Epoch   9 Batch   72/275 - Train Accuracy: 0.9717, Validation Accuracy: 0.9667, Loss: 0.0242
# Epoch   9 Batch   78/275 - Train Accuracy: 0.9745, Validation Accuracy: 0.9725, Loss: 0.0191
# Epoch   9 Batch   84/275 - Train Accuracy: 0.9678, Validation Accuracy: 0.9668, Loss: 0.0178
# Epoch   9 Batch   90/275 - Train Accuracy: 0.9716, Validation Accuracy: 0.9703, Loss: 0.0222
# Epoch   9 Batch   96/275 - Train Accuracy: 0.9697, Validation Accuracy: 0.9698, Loss: 0.0231
# Epoch   9 Batch  102/275 - Train Accuracy: 0.9820, Validation Accuracy: 0.9739, Loss: 0.0222
# Epoch   9 Batch  108/275 - Train Accuracy: 0.9750, Validation Accuracy: 0.9645, Loss: 0.0197
# Epoch   9 Batch  114/275 - Train Accuracy: 0.9770, Validation Accuracy: 0.9603, Loss: 0.0224
# Epoch   9 Batch  120/275 - Train Accuracy: 0.9720, Validation Accuracy: 0.9605, Loss: 0.0181
# Epoch   9 Batch  126/275 - Train Accuracy: 0.9640, Validation Accuracy: 0.9668, Loss: 0.0243
# Epoch   9 Batch  132/275 - Train Accuracy: 0.9710, Validation Accuracy: 0.9640, Loss: 0.0178
# Epoch   9 Batch  138/275 - Train Accuracy: 0.9778, Validation Accuracy: 0.9619, Loss: 0.0190
# Epoch   9 Batch  144/275 - Train Accuracy: 0.9748, Validation Accuracy: 0.9669, Loss: 0.0228
# Epoch   9 Batch  150/275 - Train Accuracy: 0.9758, Validation Accuracy: 0.9685, Loss: 0.0212
# Epoch   9 Batch  156/275 - Train Accuracy: 0.9747, Validation Accuracy: 0.9691, Loss: 0.0185
# Epoch   9 Batch  162/275 - Train Accuracy: 0.9646, Validation Accuracy: 0.9776, Loss: 0.0273
# Epoch   9 Batch  168/275 - Train Accuracy: 0.9772, Validation Accuracy: 0.9681, Loss: 0.0204
# Epoch   9 Batch  174/275 - Train Accuracy: 0.9688, Validation Accuracy: 0.9649, Loss: 0.0218
# Epoch   9 Batch  180/275 - Train Accuracy: 0.9669, Validation Accuracy: 0.9672, Loss: 0.0321
# Epoch   9 Batch  186/275 - Train Accuracy: 0.9665, Validation Accuracy: 0.9683, Loss: 0.0240
# Epoch   9 Batch  192/275 - Train Accuracy: 0.9677, Validation Accuracy: 0.9679, Loss: 0.0239
# Epoch   9 Batch  198/275 - Train Accuracy: 0.9770, Validation Accuracy: 0.9678, Loss: 0.0211
# Epoch   9 Batch  204/275 - Train Accuracy: 0.9810, Validation Accuracy: 0.9748, Loss: 0.0198
# Epoch   9 Batch  210/275 - Train Accuracy: 0.9866, Validation Accuracy: 0.9747, Loss: 0.0208
# Epoch   9 Batch  216/275 - Train Accuracy: 0.9728, Validation Accuracy: 0.9703, Loss: 0.0196
# Epoch   9 Batch  222/275 - Train Accuracy: 0.9697, Validation Accuracy: 0.9655, Loss: 0.0200
# Epoch   9 Batch  228/275 - Train Accuracy: 0.9710, Validation Accuracy: 0.9696, Loss: 0.0166
# Epoch   9 Batch  234/275 - Train Accuracy: 0.9770, Validation Accuracy: 0.9650, Loss: 0.0154
# Epoch   9 Batch  240/275 - Train Accuracy: 0.9794, Validation Accuracy: 0.9720, Loss: 0.0194
# Epoch   9 Batch  246/275 - Train Accuracy: 0.9789, Validation Accuracy: 0.9661, Loss: 0.0171
# Epoch   9 Batch  252/275 - Train Accuracy: 0.9734, Validation Accuracy: 0.9618, Loss: 0.0199
# Epoch   9 Batch  258/275 - Train Accuracy: 0.9776, Validation Accuracy: 0.9646, Loss: 0.0166
# Epoch   9 Batch  264/275 - Train Accuracy: 0.9769, Validation Accuracy: 0.9623, Loss: 0.0193
# Epoch   9 Batch  270/275 - Train Accuracy: 0.9669, Validation Accuracy: 0.9665, Loss: 0.0233
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int, unk_token='<UNK>'):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    tokens = [w for w in sentence.lower().split()]
    return [vocab_to_int[w] if w in vocab_to_int else vocab_to_int[unk_token] for w in tokens]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentences = [
    'he saw a old yellow truck .',
    'i am very hungry .',
    'what is your name ?',
    'the dog is angry .',
    'how old are you ?',
    'i live in the united states',
    'summer is hot'
]

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
    
    translate_logits = []
    for translate_sentence in translate_sentences:
        translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)
        translate_logits.append(sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0])

for translate_sentence, logits in zip(translate_sentences, translate_logits):
    translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)
    print('Input')
    print('  Word Ids:      {}'.format([i for i in translate_sentence]))
    print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

    print('\nPrediction')
    print('  Word Ids:      {}'.format([i for i in logits]))
    print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in logits])))
    print('-'*80)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [186, 211, 74, 112, 140, 11, 49]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [124, 29, 215, 255, 338, 163, 177, 302, 1]
#   French Words: il a vu un vieux camion jaune . <EOS>
# --------------------------------------------------------------------------------
# Input
#   Word Ids:      [141, 93, 2, 2, 49]
#   English Words: ['i', 'am', '<UNK>', '<UNK>', '.']
#
# Prediction
#   Word Ids:      [115, 249, 53, 240, 302, 1]
#   French Words: je prévois , juin . <EOS>
# --------------------------------------------------------------------------------
# Input
#   Word Ids:      [2, 108, 220, 2, 36]
#   English Words: ['<UNK>', 'is', 'your', '<UNK>', '?']
#
# Prediction
#   Word Ids:      [97, 66, 268, 348, 53, 181, 142, 302, 1]
#   French Words: votre fruit le plus , mais l'orange . <EOS>
# --------------------------------------------------------------------------------
# Input
#   Word Ids:      [48, 179, 108, 2, 49]
#   English Words: ['the', 'dog', 'is', '<UNK>', '.']
#
# Prediction
#   Word Ids:      [268, 292, 121, 149, 302, 1]
#   French Words: le chien est chine . <EOS>
# --------------------------------------------------------------------------------
# Input
#   Word Ids:      [105, 112, 145, 19, 36]
#   English Words: ['how', 'old', 'are', 'you', '?']
#
# Prediction
#   Word Ids:      [188, 194, 97, 50, 302, 1]
#   French Words: comment était votre états-unis . <EOS>
# --------------------------------------------------------------------------------
# Input
#   Word Ids:      [141, 2, 190, 48, 13, 102]
#   English Words: ['i', '<UNK>', 'in', 'the', 'united', 'states']
#
# Prediction
#   Word Ids:      [6, 201, 343, 302, 1]
#   French Words: j'aime les bananes . <EOS>
# --------------------------------------------------------------------------------
# Input
#   Word Ids:      [67, 108, 208]
#   English Words: ['summer', 'is', 'hot']
#
# Prediction
#   Word Ids:      [113, 346, 10, 302, 1]
#   French Words: paris au printemps . <EOS>
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
