# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here

# Compute word frequency.

word_freq = {}
for w in int_words:
    if w in word_freq:
        word_freq[w] += 1
    else:
        word_freq[w] = 1
        
# Compute probability of discarding words.
total_count = len(int_words)
discard_thresh = 1.0e-5
discard_prob = {}
for w in word_freq.keys():
    discard_prob[w] = 1.0 - np.sqrt(discard_thresh/(word_freq[w]/total_count))

# The final subsampled word list
train_words = []
for w in int_words:
    if np.random.uniform() > discard_prob[w]:
        train_words.append(w)

# %%
print("Total words: {}".format(len(train_words)))
print("We selected {:.2f}% of the words.".format(100.0*len(train_words)/len(words)))
print("Unique words: {}".format(len(set(train_words))))
# Out:
# Total words: 4627121
# We selected 27.74% of the words.
# Unique words: 63641

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    window_start = idx - window_size
    if window_start < 0: window_start = 0
    window_end = idx + window_size + 1
    if window_end > len(words): window_end = len(words)
    
    # Generate a list of window-words and distance from index.
    history_words = list(zip(words[window_start:idx], range(idx - window_start, 0, -1)))
    future_words = list(zip(words[idx+1:window_end], range(1, window_end - idx)))
    
    # Convert distance from index to a sampling probability.
    norm = 1.0/np.sum([1.0/d for d in range(1, window_size+1)])
    history_words = [(w, norm*1.0/d) for (w, d) in history_words]
    future_words = [(w, norm*1.0/d) for (w, d) in future_words]
    
    # Sample words.
    words_to_sample = np.random.randint(1, window_size + 1)
    sampled_words = []
    for _ in range(words_to_sample):
        cum_prob = 0.0
        rand = np.random.uniform()
        for (w,p) in history_words:
            cum_prob += p
            if cum_prob > rand:
                sampled_words.append(w)
                break
                
        cum_prob = 0.0
        rand = np.random.uniform()
        for (w,p) in future_words:
            cum_prob += p
            if cum_prob > rand:
                sampled_words.append(w)
                break
    
    return sampled_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
#vocabulary_size = len(set(words))
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, (None), name='inputs')
    labels = tf.placeholder(tf.int32, (None, None), name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1.0, maxval=1.0)) 
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.5849 0.3167 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6007 0.3133 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4703 0.3138 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5650 0.3144 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4375 0.3136 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4834 0.3129 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5255 0.3137 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4992 0.3149 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4575 0.3143 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4029 0.3165 sec/batch
# Nearest to his: ments, opponents, toon, wintertime, guthrum, infield, scalia, serial,
# Nearest to history: shoes, birthstone, speer, operatorname, redeveloped, blob, salination, citigroup,
# Nearest to by: famille, revenues, mad, ekron, koufax, restoring, hazrat, vanguard,
# Nearest to up: notations, pechenegs, miletus, lysergic, fray, va, claudio, davidian,
# Nearest to all: genealogies, wt, broch, orchestrating, phantom, iron, surgery, fertilisation,
# Nearest to during: episcopal, ionization, ote, fca, coffin, symbolise, badger, therese,
# Nearest to used: seton, alva, shelley, arching, bundles, pstn, soaking, tso,
# Nearest to from: unfermented, wards, soares, outright, kenilworth, organizations, location, counterattacks,
# Nearest to quite: auroral, vld, congregationalist, surinam, huey, positron, investigating, notes,
# Nearest to proposed: negatives, harder, repainted, means, topping, daikaiju, vinci, zf,
# Nearest to scale: vice, renew, chernenko, embryo, exceptionally, claremont, reginald, spider,
# Nearest to resources: mccoy, minicomputer, catalyze, combs, transhumanism, scientology, advantageous, vegetarianism,
# Nearest to brother: perverse, ariary, citadels, violently, leopoldine, money, athabaskan, rykov,
# Nearest to writers: dell, designated, pillaging, physicians, illuminations, handsomest, renounce, superchargers,
# Nearest to freedom: humus, sholes, crannog, innovator, declination, chiral, woolly, rijndael,
# Nearest to derived: clark, elevates, gold, exorbitant, lockheed, weblog, predators, urd,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5071 0.3225 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4237 0.3195 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3659 0.3166 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.3073 0.3167 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2687 0.3158 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2726 0.3169 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.2405 0.3167 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1910 0.3180 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.1672 0.3181 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.1709 0.3186 sec/batch
# Nearest to his: ments, toon, opponents, wintertime, serial, variants, kd, infield,
# Nearest to history: shoes, operatorname, speer, redeveloped, birthstone, refined, raids, birnbaum,
# Nearest to by: within, mad, frequently, these, koufax, critics, revenues, completion,
# Nearest to up: notations, bandmate, lysergic, pechenegs, quickly, fray, va, seattle,
# Nearest to all: genealogies, vulnerable, on, surgery, orchestrating, iron, urged, broch,
# Nearest to during: episcopal, ionization, fca, single, coffin, badger, fiendish, psychoactive,
# Nearest to used: seton, rational, key, other, introduce, pstn, shelley, bundles,
# Nearest to from: organizations, outright, location, wards, kenilworth, secure, soares, publication,
# Nearest to quite: auroral, notes, huey, home, investigating, relevance, positron, idea,
# Nearest to proposed: means, harder, negatives, zf, l, topping, repainted, ivf,
# Nearest to scale: vice, chernenko, renew, embryo, exceptionally, spider, claremont, prosecutor,
# Nearest to resources: mccoy, minicomputer, saturdays, combs, troops, transhumanism, scientology, vulnerability,
# Nearest to brother: perverse, violently, ariary, money, athabaskan, citadels, leopoldine, rykov,
# Nearest to writers: dell, designated, physicians, pillaging, handsomest, illuminations, superchargers, boca,
# Nearest to freedom: declination, humus, rijndael, innovator, sholes, meant, woolly, chiral,
# Nearest to derived: any, clark, editions, gold, barrels, elevates, lockheed, exorbitant,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 5.0818 0.3207 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 5.0635 0.3160 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9879 0.3237 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9960 0.3181 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.9194 0.3190 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.9119 0.3160 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8900 0.3158 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8597 0.3156 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8207 0.3153 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8426 0.3187 sec/batch
# Nearest to his: serial, ments, opponents, toon, caused, napoleonic, institutes, wintertime,
# Nearest to history: shoes, raids, doesn, speer, refined, circumstances, redeveloped, imprisonment,
# Nearest to by: revenues, within, completion, nations, mad, restoring, legislation, critics,
# Nearest to up: quickly, notations, va, seattle, bandmate, stand, lysergic, sponsorship,
# Nearest to all: genealogies, iron, on, vulnerable, urged, steep, phantom, orchestrating,
# Nearest to during: episcopal, ionization, fca, became, single, coffin, tone, tallest,
# Nearest to used: introduce, seton, rational, key, arching, likely, shelley, alva,
# Nearest to from: outright, organizations, wards, acclaimed, secure, kenilworth, soares, publication,
# Nearest to quite: notes, auroral, relevance, home, investigating, elsewhere, huey, idea,
# Nearest to proposed: means, harder, substantially, l, negatives, zf, topping, lanka,
# Nearest to scale: vice, chernenko, formed, renew, embryo, spider, coastal, exceptionally,
# Nearest to resources: mccoy, minicomputer, saturdays, troops, bringing, cinematography, caucasian, merlin,
# Nearest to brother: violently, perverse, money, fully, ariary, debates, athabaskan, marshal,
# Nearest to writers: designated, dell, physicians, pillaging, handsomest, boca, superchargers, interfaces,
# Nearest to freedom: humus, innovator, declination, ibm, meant, commonwealth, speech, condemned,
# Nearest to derived: editions, any, gold, lockheed, finish, predators, barrels, imperfective,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8436 0.3177 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8010 0.3163 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7720 0.3219 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7506 0.3189 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7967 0.3161 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7350 0.3182 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7517 0.3163 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7554 0.3168 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7369 0.3163 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6767 0.3156 sec/batch
# Nearest to his: serial, ments, fearing, toon, napoleonic, risen, witold, kwaidan,
# Nearest to history: shoes, speer, redeveloped, raids, imprisonment, refined, operatorname, birthstone,
# Nearest to by: revenues, within, legislation, mad, restoring, completion, tr, critics,
# Nearest to up: notations, quickly, seattle, sponsorship, graduated, pechenegs, claudio, arose,
# Nearest to all: genealogies, iron, vulnerable, steep, orchestrating, handful, phantom, broch,
# Nearest to during: episcopal, ionization, became, coffin, fca, lithuanian, symbolise, neighbouring,
# Nearest to used: seton, introduce, bundles, pity, newcomers, arching, alva, rational,
# Nearest to from: outright, wards, organizations, acclaimed, kenilworth, refuse, localized, soares,
# Nearest to quite: auroral, notes, relevance, investigating, huey, surinam, idea, terrain,
# Nearest to proposed: means, harder, negatives, substantially, topping, l, zf, oswego,
# Nearest to scale: renew, embryo, chernenko, vice, formed, spider, coastal, exceptionally,
# Nearest to resources: mccoy, minicomputer, saturdays, troops, advantageous, combs, cinematography, bringing,
# Nearest to brother: perverse, violently, fully, money, leopoldine, ariary, marshal, debates,
# Nearest to writers: dell, designated, physicians, pillaging, boca, handsomest, easton, illuminations,
# Nearest to freedom: humus, declination, innovator, comprehend, ibm, autographed, christiaan, speech,
# Nearest to derived: predators, editions, fonts, lockheed, any, imperfective, barrels, gold,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6874 0.3207 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6682 0.3177 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6426 0.3183 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6686 0.3221 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6578 0.3238 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6461 0.3211 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6282 0.2352 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5661 0.3237 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5260 0.3257 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5483 0.3230 sec/batch
# Nearest to his: witold, serial, ments, kwaidan, oscillatory, fearing, dewitt, risen,
# Nearest to history: shoes, speer, redeveloped, birthstone, raids, slovakia, rhodesia, refined,
# Nearest to by: revenues, within, vanguard, mad, koufax, restoring, constrain, tr,
# Nearest to up: quickly, notations, claudio, seattle, miletus, pechenegs, sponsorship, swell,
# Nearest to all: genealogies, vulnerable, handful, steep, broch, on, urged, orchestrating,
# Nearest to during: episcopal, ionization, became, coffin, neighbouring, fca, burgundy, springs,
# Nearest to used: bundles, seton, introduce, pity, newcomers, rational, other, arching,
# Nearest to from: outright, localized, organizations, kenilworth, insisting, wards, refuse, acclaimed,
# Nearest to quite: auroral, positron, notes, surinam, investigating, huey, relevance, maps,
# Nearest to proposed: means, negatives, harder, topping, lanka, substantially, famines, nigerian,
# Nearest to scale: chernenko, embryo, renew, vice, formed, spider, exceptionally, objects,
# Nearest to resources: minicomputer, mccoy, saturdays, troops, advantageous, caucasian, combs, vegetarianism,
# Nearest to brother: violently, perverse, leopoldine, marshal, citadels, fully, ariary, taoism,
# Nearest to writers: dell, designated, physicians, handsomest, easton, dredged, boca, illuminations,
# Nearest to freedom: humus, declination, speech, innovator, chiral, christiaan, autographed, comprehend,
# Nearest to derived: predators, fonts, imperfective, editions, weblog, any, exorbitant, gold,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5132 0.3256 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5055 0.3205 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4658 0.3196 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5642 0.3212 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5256 0.3198 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5036 0.3208 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4796 0.3200 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4172 0.3209 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4450 0.3195 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4484 0.3200 sec/batch
# Nearest to his: witold, oscillatory, ments, feast, fearing, poets, brahman, napoleonic,
# Nearest to history: shoes, speer, redeveloped, slovakia, raids, rhodesia, birthstone, exacting,
# Nearest to by: revenues, koufax, mad, restoring, constrain, within, hazrat, legislation,
# Nearest to up: quickly, miletus, notations, swell, sponsorship, pechenegs, oxidizes, diligently,
# Nearest to all: genealogies, broch, handful, vulnerable, miscarriage, honda, standard, precise,
# Nearest to during: episcopal, ionization, became, excepted, neighbouring, fca, coffin, therese,
# Nearest to used: bundles, seton, pity, rational, newcomers, introduce, removing, coastlands,
# Nearest to from: outright, localized, organizations, refuse, insisting, neutralize, communally, fictitious,
# Nearest to quite: positron, auroral, surinam, relevance, notes, congregationalist, huey, depending,
# Nearest to proposed: means, harder, negatives, zf, substantially, famines, lanka, topping,
# Nearest to scale: chernenko, embryo, vice, renew, formed, spider, objects, anything,
# Nearest to resources: minicomputer, mccoy, advantageous, merlin, caucasian, cth, ripened, vegetarianism,
# Nearest to brother: violently, marshal, perverse, leopoldine, citadels, ariary, taoism, armaments,
# Nearest to writers: dell, designated, easton, physicians, illuminations, dredged, handsomest, barfield,
# Nearest to freedom: declination, humus, speech, sholes, chiral, innovator, commonwealth, petar,
# Nearest to derived: predators, choking, fonts, imperfective, exorbitant, weblog, any, circumstance,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4634 0.3250 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3978 0.3190 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4468 0.3255 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4142 0.3274 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4055 0.3238 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4327 0.3172 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3898 0.3198 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3834 0.3187 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4138 0.3182 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3698 0.3176 sec/batch
# Nearest to his: kwaidan, ments, witold, oscillatory, poets, feast, fearing, brahman,
# Nearest to history: shoes, speer, redeveloped, rhodesia, slovakia, birthstone, raids, exacting,
# Nearest to by: mad, revenues, critics, koufax, hazrat, mexica, famille, constrain,
# Nearest to up: oxidizes, swell, sponsorship, notations, quickly, stand, pechenegs, diligently,
# Nearest to all: genealogies, broch, honda, vulnerable, tricolor, understands, miscarriage, handful,
# Nearest to during: episcopal, ionization, became, excepted, coffin, therese, neighbouring, fca,
# Nearest to used: seton, bundles, pity, introduce, rational, removing, newcomers, coastlands,
# Nearest to from: outright, communally, localized, insisting, fictitious, organizations, wards, refuse,
# Nearest to quite: surinam, positron, relevance, auroral, huey, notes, congregationalist, rayleigh,
# Nearest to proposed: means, negatives, harder, substantially, lanka, famines, zf, topping,
# Nearest to scale: embryo, chernenko, vice, emblazoned, formed, objects, anything, apart,
# Nearest to resources: minicomputer, advantageous, cth, mccoy, ripened, merlin, vegetarianism, caucasian,
# Nearest to brother: marshal, violently, perverse, leopoldine, citadels, taoism, ariary, qing,
# Nearest to writers: dell, easton, designated, physicians, dredged, illuminations, charles, barfield,
# Nearest to freedom: speech, declination, sholes, connotation, chiral, humus, autographed, katal,
# Nearest to derived: predators, choking, elevates, imperfective, exorbitant, fonts, any, weblog,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3559 0.3226 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3597 0.3191 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3343 0.3180 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3512 0.3172 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3538 0.3179 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3686 0.3186 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3829 0.3201 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3701 0.3186 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3249 0.3197 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3181 0.3187 sec/batch
# Nearest to his: feast, ments, oscillatory, witold, kwaidan, confess, fearing, brahman,
# Nearest to history: shoes, speer, redeveloped, rhodesia, slovakia, birthstone, hebrews, transcends,
# Nearest to by: hazrat, revenues, aster, vanguard, critics, restoring, within, trusteeship,
# Nearest to up: sponsorship, pechenegs, oxidizes, stand, quickly, swell, miletus, diligently,
# Nearest to all: genealogies, on, broch, that, human, mccune, honda, beyond,
# Nearest to during: episcopal, excepted, ionization, became, the, coffin, fca, neighbouring,
# Nearest to used: introduce, seton, coastlands, oscilloscopes, bundles, condition, removing, truncation,
# Nearest to from: outright, localized, communally, northern, fictitious, refuse, wards, insisting,
# Nearest to quite: surinam, relevance, positron, congregationalist, huey, auroral, notes, depending,
# Nearest to proposed: means, negatives, substantially, harder, principal, lanka, famines, cinq,
# Nearest to scale: embryo, chernenko, formed, emblazoned, objects, synching, vice, traction,
# Nearest to resources: minicomputer, cth, ripened, advantageous, mccoy, merlin, ore, arable,
# Nearest to brother: marshal, violently, leopoldine, perverse, bishkek, ariary, citadels, age,
# Nearest to writers: dell, easton, physicians, dredged, designated, illuminations, barfield, charles,
# Nearest to freedom: speech, connotation, declination, condemned, semite, autographed, amulets, sholes,
# Nearest to derived: predators, choking, imperfective, any, exorbitant, elevates, fonts, declension,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3105 0.3244 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2887 0.3186 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3690 0.3208 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3788 0.3179 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3688 0.3192 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2881 0.3195 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2955 0.3185 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3364 0.3181 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2223 0.3192 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2718 0.3189 sec/batch
# Nearest to his: ments, oscillatory, kwaidan, fearing, witold, tombstone, improvise, sportsmanship,
# Nearest to history: shoes, redeveloped, rhodesia, speer, slovakia, birthstone, retells, hebrews,
# Nearest to by: legislation, vanguard, aster, hazrat, constrain, revenues, obeying, curie,
# Nearest to up: sponsorship, lap, oxidizes, alemannia, quickly, diligently, pechenegs, swell,
# Nearest to all: genealogies, broch, honda, vulnerable, chur, on, mccune, miscarriage,
# Nearest to during: excepted, became, episcopal, neighbouring, ionization, was, ote, coffin,
# Nearest to used: truncation, introduce, coastlands, oscilloscopes, removing, pity, bundles, evaluate,
# Nearest to from: outright, localized, communally, fictitious, galileo, wards, rutgers, northern,
# Nearest to quite: surinam, huey, notes, relevance, congregationalist, positron, auroral, vld,
# Nearest to proposed: means, negatives, principal, substantially, withhold, harder, lanka, cinq,
# Nearest to scale: embryo, chernenko, formed, emblazoned, synching, traction, objects, renew,
# Nearest to resources: arable, minicomputer, cth, ore, woolen, droughts, ripened, antipodal,
# Nearest to brother: marshal, violently, leopoldine, perverse, age, bishkek, poulenc, qing,
# Nearest to writers: dell, easton, physicians, dredged, masterwork, illuminations, barfield, books,
# Nearest to freedom: speech, connotation, declination, blaming, condemned, autographed, sholes, semite,
# Nearest to derived: predators, choking, omnipotent, imperfective, exorbitant, declension, ngc, perspectives,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2729 0.3220 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2790 0.3179 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3125 0.1466 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2557 0.3169 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2026 0.3193 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2173 0.3195 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1753 0.3186 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1960 0.3205 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2016 0.3199 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1593 0.3191 sec/batch
# Nearest to his: oscillatory, drowned, ments, kwaidan, he, witold, opponents, tombstone,
# Nearest to history: shoes, speer, redeveloped, rhodesia, slovakia, birthstone, hebrews, blob,
# Nearest to by: vanguard, constrain, legislation, hazrat, reports, restoring, revenues, aster,
# Nearest to up: quickly, sponsorship, oxidizes, pechenegs, lap, alemannia, too, orser,
# Nearest to all: genealogies, broch, honda, chur, mccune, miscarriage, handful, guidance,
# Nearest to during: excepted, ionization, became, episcopal, ote, neighbouring, were, plotters,
# Nearest to used: coastlands, truncation, oscilloscopes, introduce, removing, seton, mashed, discretization,
# Nearest to from: outright, localized, communally, northern, galileo, ji, wards, fictitious,
# Nearest to quite: surinam, huey, relevance, positron, notes, congregationalist, stressed, hz,
# Nearest to proposed: negatives, means, principal, withhold, substantially, zf, harder, cinq,
# Nearest to scale: embryo, emblazoned, chernenko, traction, synching, formed, uneven, renew,
# Nearest to resources: arable, cth, droughts, minicomputer, woolen, ore, antipodal, caucasian,
# Nearest to brother: marshal, violently, leopoldine, burgundy, bishkek, perverse, sardinia, baptism,
# Nearest to writers: dell, easton, masterwork, dredged, barfield, physicians, books, dykes,
# Nearest to freedom: speech, connotation, condemned, blaming, katal, autographed, semite, declination,
# Nearest to derived: imperfective, predators, choking, ngc, exorbitant, omnipotent, editions, perspectives,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2205 0.3229 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1736 0.3159 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1861 0.3171 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1080 0.3168 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1241 0.3180 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1399 0.3178 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1004 0.3174 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1347 0.3167 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1708 0.3171 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1339 0.3169 sec/batch
# Nearest to his: ments, witold, fearing, keaton, sportsmanship, tombstone, opponents, drowned,
# Nearest to history: shoes, speer, rhodesia, redeveloped, transcends, slovakia, hebrews, birthstone,
# Nearest to by: constrain, vanguard, spilling, solstices, hazrat, obeying, legislation, revenues,
# Nearest to up: quickly, sponsorship, pechenegs, oxidizes, too, lap, quebecois, swell,
# Nearest to all: genealogies, honda, broch, miscarriage, mccune, chur, guidance, overlap,
# Nearest to during: ionization, excepted, became, ote, were, episcopal, tender, fca,
# Nearest to used: coastlands, oscilloscopes, truncation, other, seton, risky, discretization, newcomers,
# Nearest to from: localized, communally, outright, ji, neutralize, galileo, fictitious, refuse,
# Nearest to quite: surinam, huey, relevance, positron, notes, hz, auroral, stressed,
# Nearest to proposed: principal, means, negatives, divest, substantially, withhold, zf, harder,
# Nearest to scale: embryo, traction, formed, emblazoned, synching, chernenko, apart, notes,
# Nearest to resources: arable, cth, ore, droughts, minicomputer, woolen, ripened, forests,
# Nearest to brother: marshal, violently, perverse, poulenc, age, leopoldine, clement, sardinia,
# Nearest to writers: dell, easton, masterwork, barfield, books, dredged, physicians, dykes,
# Nearest to freedom: speech, connotation, condemned, laws, blaming, amulets, semite, declination,
# Nearest to derived: imperfective, choking, predators, exorbitant, bribed, omnipotent, ngc, elevates,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1147 0.3212 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1844 0.3165 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1341 0.3165 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1246 0.3170 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1550 0.3153 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1208 0.3170 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1683 0.3168 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.0746 0.3158 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.0712 0.3175 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1290 0.3173 sec/batch
# Nearest to his: ments, tombstone, fearing, sportsmanship, opponents, pepys, he, witold,
# Nearest to history: speer, rhodesia, shoes, redeveloped, hebrews, transcends, korca, slovakia,
# Nearest to by: vanguard, takings, legislation, obeying, especial, hazrat, solstices, spilling,
# Nearest to up: lap, quickly, sponsorship, pechenegs, too, swell, oxidizes, quebecois,
# Nearest to all: genealogies, broch, honda, overlap, sorceress, beyond, mccune, megalopolis,
# Nearest to during: excepted, ionization, tender, ote, were, became, coffin, authorizing,
# Nearest to used: coastlands, oscilloscopes, truncation, lip, discretization, seton, introduce, splash,
# Nearest to from: localized, communally, ji, michelob, outright, acclaimed, galileo, wards,
# Nearest to quite: surinam, huey, relevance, congregationalist, positron, hz, auroral, depending,
# Nearest to proposed: withhold, principal, means, amendment, negatives, zf, cinq, substantially,
# Nearest to scale: embryo, traction, emblazoned, formed, synching, limba, chernenko, uneven,
# Nearest to resources: arable, cth, minicomputer, droughts, ore, woolen, ripened, forests,
# Nearest to brother: violently, marshal, perverse, clement, boece, leopoldine, baptism, sardinia,
# Nearest to writers: dell, easton, barfield, masterwork, dredged, dykes, books, libertarians,
# Nearest to freedom: speech, connotation, amulets, laissez, laws, autographed, rights, condemned,
# Nearest to derived: imperfective, choking, ngc, elevates, predators, exorbitant, declension, word,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1601 0.3207 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1206 0.3175 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1111 0.3174 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1357 0.3173 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1003 0.3171 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0738 0.3163 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1152 0.3173 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0738 0.3172 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1670 0.3174 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1667 0.3180 sec/batch
# Nearest to his: tombstone, ments, sportsmanship, pepys, fearing, he, oscillatory, keaton,
# Nearest to history: rhodesia, speer, redeveloped, transcends, hebrews, slovakia, shoes, korca,
# Nearest to by: vanguard, reports, gnaeus, legislation, hazrat, restoring, especial, takings,
# Nearest to up: sponsorship, lap, quebecois, pechenegs, davidian, stand, bull, orser,
# Nearest to all: genealogies, broch, honda, megalopolis, mccune, beyond, oeis, overlap,
# Nearest to during: excepted, became, were, ionization, ote, gaulle, episcopal, plotters,
# Nearest to used: oscilloscopes, discretization, coastlands, use, truncation, splash, ssl, lip,
# Nearest to from: localized, wards, outright, ji, acclaimed, eloheinu, insisting, michelob,
# Nearest to quite: surinam, huey, relevance, congregationalist, antoninianus, hz, depending, notes,
# Nearest to proposed: withhold, amendment, principal, cinq, means, substantially, nigerian, divest,
# Nearest to scale: notes, traction, embryo, emblazoned, synching, chernenko, uneven, limba,
# Nearest to resources: arable, cth, droughts, ore, hydropower, forests, minicomputer, woolen,
# Nearest to brother: marshal, violently, baptism, age, perverse, eldest, leopoldine, sardinia,
# Nearest to writers: dell, easton, barfield, masterwork, dykes, books, dredged, libertarians,
# Nearest to freedom: speech, blaming, connotation, rights, autographed, amulets, laissez, complying,
# Nearest to derived: imperfective, choking, perspectives, predators, ngc, omnipotent, elevates, prepositional,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1606 0.3209 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0904 0.3161 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0667 0.3223 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.0813 0.3194 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0139 0.3191 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.0735 0.3257 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.0834 0.3210 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0515 0.3183 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1256 0.0607 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0585 0.3189 sec/batch
# Nearest to his: tombstone, ments, he, pepys, awaits, oscillatory, himself, fearing,
# Nearest to history: rhodesia, speer, redeveloped, slovakia, transcends, shoes, hebrews, albertus,
# Nearest to by: takings, obeying, vanguard, riaa, aster, especial, solstices, bem,
# Nearest to up: lap, sponsorship, speeds, crafting, quebecois, oxidizes, pechenegs, quickly,
# Nearest to all: genealogies, honda, broch, approximates, landowner, megalopolis, mccune, overlap,
# Nearest to during: excepted, ionization, were, ote, became, plotters, episcopal, abernathy,
# Nearest to used: truncation, oscilloscopes, use, coastlands, ssl, pstn, are, introduce,
# Nearest to from: localized, galileo, outright, ji, fictitious, communally, michelob, vassal,
# Nearest to quite: surinam, huey, relevance, visor, hz, depending, positron, antoninianus,
# Nearest to proposed: withhold, amendment, principal, means, nigerian, substantially, judgments, negatives,
# Nearest to scale: notes, traction, embryo, emblazoned, scales, synching, chernenko, uneven,
# Nearest to resources: arable, cth, droughts, ore, forests, minicomputer, hydropower, woolen,
# Nearest to brother: marshal, violently, sardinia, perverse, baptism, boece, eldest, leopoldine,
# Nearest to writers: dell, easton, barfield, masterwork, dykes, dredged, books, pwned,
# Nearest to freedom: speech, blaming, connotation, amulets, autographed, laissez, grue, olimp,
# Nearest to derived: perspectives, imperfective, prepositional, choking, exorbitant, declension, ngc, descends,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0029 0.3225 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0017 0.3193 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0233 0.3197 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.9834 0.3181 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0329 0.3178 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9637 0.3177 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0317 0.3175 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0318 0.3181 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0465 0.3192 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9651 0.3183 sec/batch
# Nearest to his: tombstone, awaits, pepys, guthrum, he, confess, sportsmanship, ments,
# Nearest to history: rhodesia, redeveloped, transcends, speer, astronautica, slovakia, ru, albertus,
# Nearest to by: rearwards, obeying, takings, trusteeship, retaliated, spilling, especial, aster,
# Nearest to up: pechenegs, loma, speeds, quickly, crafting, orser, quebecois, lap,
# Nearest to all: genealogies, honda, broch, approximates, installations, sorceress, overlap, megalopolis,
# Nearest to during: excepted, ionization, plotters, ote, were, became, hajj, was,
# Nearest to used: use, coastlands, truncation, oscilloscopes, discretization, risky, ssl, other,
# Nearest to from: localized, outright, communally, ji, galileo, michelob, fictitious, motoring,
# Nearest to quite: surinam, huey, hz, visor, depending, relevance, rayleigh, antoninianus,
# Nearest to proposed: withhold, amendment, zf, principal, divest, means, nigerian, rider,
# Nearest to scale: notes, traction, scales, emblazoned, embryo, synching, chernenko, wide,
# Nearest to resources: arable, cth, droughts, ore, minicomputer, forests, hydropower, woolen,
# Nearest to brother: violently, marshal, sardinia, boece, perverse, clement, baptism, son,
# Nearest to writers: easton, dell, barfield, masterwork, dykes, pwned, libertarians, novelists,
# Nearest to freedom: speech, blaming, autographed, connotation, grue, laissez, amulets, olimp,
# Nearest to derived: imperfective, ngc, perspectives, dialects, descends, prepositional, declension, choking,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9434 0.3210 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9834 0.3194 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9455 0.3183 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.9822 0.3181 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.9965 0.3201 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.9907 0.3184 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.9871 0.3186 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0267 0.3172 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0020 0.3184 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.9732 0.3174 sec/batch
# Nearest to his: tombstone, ments, pepys, sportsmanship, fearing, oscillatory, awaits, guthrum,
# Nearest to history: transcends, redeveloped, rhodesia, speer, astronautica, albertus, hebrews, slovakia,
# Nearest to by: obeying, rearwards, takings, trusteeship, hazrat, solstices, legislation, famille,
# Nearest to up: speeds, crafting, pechenegs, oxidizes, quickly, davidian, quebecois, lap,
# Nearest to all: genealogies, honda, overlap, approximates, injection, sorceress, are, broch,
# Nearest to during: ionization, excepted, ote, became, plotters, hajj, were, venosus,
# Nearest to used: use, truncation, thalweg, ssl, coastlands, oscilloscopes, ingredients, covalently,
# Nearest to from: localized, michelob, fictitious, communally, ji, insisting, disclosing, children,
# Nearest to quite: surinam, huey, relevance, hz, depending, visor, rayleigh, positron,
# Nearest to proposed: withhold, amendment, zf, principal, model, judgments, rider, substantially,
# Nearest to scale: notes, traction, scales, synching, chernenko, emblazoned, embryo, uneven,
# Nearest to resources: arable, cth, ore, forests, droughts, minicomputer, hydropower, ripened,
# Nearest to brother: violently, marshal, perverse, boece, clement, sardinia, son, sentenced,
# Nearest to writers: easton, barfield, dell, novelists, dykes, masterwork, pwned, libertarians,
# Nearest to freedom: speech, blaming, autographed, connotation, laissez, grue, rights, olimp,
# Nearest to derived: imperfective, descends, declension, ngc, elevates, prepositional, slovenian, perspectives,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.9692 0.3233 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0335 0.3175 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0079 0.3180 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9544 0.3177 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.9872 0.3169 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.9944 0.3170 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.9904 0.3172 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0082 0.3189 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0228 0.3168 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.9798 0.3175 sec/batch
# Nearest to his: tombstone, he, pepys, ments, guthrum, confess, himself, fearing,
# Nearest to history: rhodesia, transcends, speer, redeveloped, slovakia, hebrews, albertus, astronautica,
# Nearest to by: obeying, takings, shortly, rearwards, hazrat, legislation, spilling, especial,
# Nearest to up: lap, speeds, crafting, pechenegs, quebecois, czechoslovakian, orser, davidian,
# Nearest to all: genealogies, honda, approximates, overlap, broch, sihamoni, megalopolis, sorceress,
# Nearest to during: ionization, excepted, ote, the, shaoqi, plotters, hajj, were,
# Nearest to used: use, thalweg, discretization, ingredients, broccoli, truncation, seton, other,
# Nearest to from: localized, galileo, fictitious, michelob, vassal, communally, ji, outright,
# Nearest to quite: surinam, huey, relevance, hz, visor, depending, iru, sophisticated,
# Nearest to proposed: withhold, amendment, principal, koruna, model, martinus, zf, substantially,
# Nearest to scale: notes, scales, traction, chernenko, uneven, embryo, emblazoned, barrage,
# Nearest to resources: arable, cth, forests, ore, minicomputer, gis, droughts, ripened,
# Nearest to brother: son, violently, boece, sardinia, eldest, clement, marshal, sister,
# Nearest to writers: barfield, easton, dell, novelists, dykes, masterwork, playwrights, books,
# Nearest to freedom: speech, blaming, autographed, laissez, connotation, olimp, grue, rights,
# Nearest to derived: imperfective, perspectives, prepositional, declension, belongs, elevates, descends, catecholamines,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.9984 0.3201 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9441 0.3179 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9502 0.3188 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.9899 0.3192 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.9950 0.3174 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0708 0.3167 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0626 0.3172 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9422 0.3172 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9431 0.3177 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.9662 0.3185 sec/batch
# Nearest to his: tombstone, ments, he, himself, pepys, oscillatory, jehoshaphat, guthrum,
# Nearest to history: astronautica, rhodesia, redeveloped, runciman, tver, speer, quinn, transcends,
# Nearest to by: takings, shortly, retaliated, obeying, trusteeship, bem, hazrat, reports,
# Nearest to up: crafting, quebecois, lap, speeds, pechenegs, orser, davidian, across,
# Nearest to all: genealogies, honda, broch, overlap, leq, landowner, approximates, sihamoni,
# Nearest to during: hajj, excepted, were, ote, ionization, became, abernathy, shaoqi,
# Nearest to used: use, discretization, truncation, ssl, other, are, aspires, rad,
# Nearest to from: localized, galileo, fictitious, peril, michelob, vassal, rutgers, ji,
# Nearest to quite: huey, surinam, relevance, hz, visor, iru, depending, sophisticated,
# Nearest to proposed: withhold, amendment, koruna, principal, lanka, substantially, nigerian, supervises,
# Nearest to scale: notes, traction, scales, tuning, embryo, chernenko, tonality, uneven,
# Nearest to resources: arable, cth, ore, forests, droughts, pastures, gis, hydropower,
# Nearest to brother: son, violently, boece, eldest, marshal, sardinia, sister, hecuba,
# Nearest to writers: novelists, barfield, dell, easton, dykes, masterwork, playwrights, books,
# Nearest to freedom: speech, blaming, laissez, connotation, autographed, rights, grue, deakin,
# Nearest to derived: imperfective, prepositional, perspectives, declension, ism, belongs, identities, elevates,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.8998 0.3215 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9334 0.3195 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9648 0.3180 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9612 0.3178 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 3.9839 0.3167 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9865 0.2920 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9303 0.3175 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9045 0.3185 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9461 0.3179 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.8603 0.3172 sec/batch
# Nearest to his: tombstone, he, himself, pepys, guthrum, jehoshaphat, drowned, ments,
# Nearest to history: astronautica, transcends, combinatorics, tver, rhodesia, summarized, quinn, albertus,
# Nearest to by: takings, shortly, obeying, bem, windmill, sikh, v, retaliated,
# Nearest to up: speeds, quebecois, pechenegs, crafting, lap, davidian, flip, orser,
# Nearest to all: genealogies, honda, broch, overlap, approximates, landowner, oeis, chakras,
# Nearest to during: hajj, ionization, excepted, badges, period, ote, were, venosus,
# Nearest to used: use, discretization, pstn, ssl, ingredients, truncation, oscilloscopes, thalweg,
# Nearest to from: localized, galileo, fictitious, michelob, vassal, peril, motoring, rutgers,
# Nearest to quite: surinam, huey, hz, relevance, visor, iru, positron, depending,
# Nearest to proposed: withhold, amendment, koruna, principal, zf, ridgway, divest, lanka,
# Nearest to scale: notes, scales, traction, tuning, octave, tonality, chernenko, emblazoned,
# Nearest to resources: arable, cth, ore, gis, forests, minicomputer, pastures, titanium,
# Nearest to brother: son, violently, sister, sardinia, eldest, boece, hecuba, sentenced,
# Nearest to writers: novelists, barfield, dell, easton, dykes, masterwork, playwrights, handsomest,
# Nearest to freedom: speech, blaming, laissez, autographed, grue, connotation, olimp, deakin,
# Nearest to derived: imperfective, prepositional, perspectives, declension, slovenian, belongs, identities, ism,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9017 0.3203 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8553 0.3173 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9371 0.3171 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9536 0.3170 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9170 0.3169 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9296 0.3174 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8377 0.3181 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.8714 0.3168 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8232 0.3157 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.8969 0.3165 sec/batch
# Nearest to his: tombstone, jehoshaphat, he, cohomology, himself, guthrum, hippolyte, ments,
# Nearest to history: combinatorics, transcends, tver, astronautica, summarized, rhodesia, albertus, geospatial,
# Nearest to by: takings, sikh, occasionally, obeying, shortly, v, anselme, trusteeship,
# Nearest to up: speeds, quebecois, crafting, davidian, pechenegs, quickly, failures, lap,
# Nearest to all: honda, genealogies, approximates, are, injection, overlap, chakras, oeis,
# Nearest to during: ionization, venosus, period, hajj, badges, fca, excepted, were,
# Nearest to used: use, discretization, ssl, other, names, ingredients, thalweg, drugs,
# Nearest to from: localized, motoring, pitman, galileo, communally, michelob, peril, fictitious,
# Nearest to quite: surinam, huey, relevance, hz, positron, visor, drugged, sophisticated,
# Nearest to proposed: withhold, amendment, principal, ridgway, divest, zf, koruna, martinus,
# Nearest to scale: notes, scales, traction, chernenko, tonality, tuning, emblazoned, tempered,
# Nearest to resources: arable, cth, gis, ore, minicomputer, forests, pastures, titanium,
# Nearest to brother: son, violently, sardinia, marshal, sentenced, boece, hecuba, clement,
# Nearest to writers: novelists, barfield, easton, playwrights, dykes, dell, masterwork, comedians,
# Nearest to freedom: speech, blaming, laissez, autographed, olimp, connotation, talionis, grue,
# Nearest to derived: imperfective, declension, prepositional, perspectives, belongs, slovenian, descends, any,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9108 0.3198 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9107 0.3173 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.8616 0.3165 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9249 0.3180 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9369 0.3186 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.8421 0.3187 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9239 0.3171 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.8983 0.3174 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9090 0.3162 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.8870 0.3190 sec/batch
# Nearest to his: tombstone, he, cohomology, guthrum, ments, jehoshaphat, einstein, hippolyte,
# Nearest to history: transcends, combinatorics, astronautica, rhodesia, tver, speer, external, albertus,
# Nearest to by: takings, obeying, anselme, v, occasionally, bem, sikh, famille,
# Nearest to up: speeds, crafting, davidian, quebecois, lap, flip, off, pechenegs,
# Nearest to all: honda, are, genealogies, overlap, landowner, leq, approximates, injection,
# Nearest to during: period, ionization, fca, era, hajj, badges, venosus, excepted,
# Nearest to used: use, names, discretization, thalweg, drugs, broccoli, rad, ssl,
# Nearest to from: localized, michelob, fictitious, galileo, pitman, peril, insisting, communally,
# Nearest to quite: surinam, huey, relevance, drugged, visor, hz, iru, sophisticated,
# Nearest to proposed: amendment, withhold, principal, martinus, divest, koruna, supervises, ridgway,
# Nearest to scale: notes, scales, traction, tempered, chernenko, tuning, tonality, possibilities,
# Nearest to resources: arable, cth, ore, gis, vegetarianism, minicomputer, pastures, hydropower,
# Nearest to brother: son, violently, sister, sardinia, sentenced, eldest, hecuba, clement,
# Nearest to writers: novelists, barfield, playwrights, dykes, comedians, easton, masterwork, dell,
# Nearest to freedom: speech, blaming, autographed, laissez, grue, olimp, connotation, amulets,
# Nearest to derived: perspectives, imperfective, belongs, declension, descends, any, prepositional, ism,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.8964 0.3232 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.8854 0.3188 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9000 0.3172 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9059 0.3173 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9311 0.3178 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9211 0.3171 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.8969 0.3178 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.8555 0.3169 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.8801 0.3262 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9373 0.3276 sec/batch
# Nearest to his: tombstone, he, guthrum, himself, met, jehoshaphat, spent, cohomology,
# Nearest to history: transcends, astronautica, external, eds, summarized, combinatorics, tver, rhodesia,
# Nearest to by: takings, trusteeship, reports, sikh, camshaft, the, occasionally, obeying,
# Nearest to up: davidian, pechenegs, sebasti, quebecois, speeds, crafting, across, lap,
# Nearest to all: honda, genealogies, are, overlap, landowner, leq, oeis, beyond,
# Nearest to during: period, ionization, era, spread, hajj, late, badges, venosus,
# Nearest to used: use, names, discretization, uses, often, drugs, thalweg, are,
# Nearest to from: localized, galileo, vassal, pitman, fictitious, communally, onwards, peril,
# Nearest to quite: surinam, huey, relevance, visor, antoninianus, hz, iru, positron,
# Nearest to proposed: withhold, amendment, principal, koruna, martinus, divest, nature, nigerian,
# Nearest to scale: notes, scales, traction, chernenko, tempered, tuning, tonality, uneven,
# Nearest to resources: arable, ore, cth, gis, pastures, hydropower, minicomputer, droughts,
# Nearest to brother: son, sister, violently, sentenced, hecuba, protectorate, sardinia, amnesiac,
# Nearest to writers: novelists, barfield, playwrights, comedians, shiraz, easton, dykes, masterwork,
# Nearest to freedom: speech, blaming, laissez, autographed, deakin, olimp, connotation, grue,
# Nearest to derived: perspectives, imperfective, ism, descends, declension, any, slovenian, prepositional,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9239 0.3460 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0060 0.3158 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 3.9331 0.3116 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 3.9287 0.3130 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.8644 0.3138 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.8361 0.3159 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.8552 0.3284 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.8308 0.3237 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.8937 0.3343 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.8755 0.3363 sec/batch
# Nearest to his: tombstone, he, guthrum, spent, pepys, jehoshaphat, himself, met,
# Nearest to history: astronautica, eds, transcends, runciman, tver, albertus, combinatorics, summarized,
# Nearest to by: camshaft, takings, trusteeship, obeying, reports, shortly, editable, windmill,
# Nearest to up: speeds, crafting, pechenegs, davidian, sebasti, quebecois, across, flip,
# Nearest to all: honda, overlap, approximates, are, leq, genealogies, tricolor, beyond,
# Nearest to during: period, era, ionization, hajj, late, lasted, venosus, excepted,
# Nearest to used: use, names, uses, oscilloscopes, truncation, discretization, often, ssl,
# Nearest to from: localized, peril, galileo, michelob, fictitious, communally, served, motoring,
# Nearest to quite: surinam, huey, iru, stressed, relevance, antoninianus, visor, hz,
# Nearest to proposed: withhold, amendment, koruna, divest, principal, ridgway, nigerian, supervises,
# Nearest to scale: notes, scales, tonality, traction, tempered, tuning, chromatic, chernenko,
# Nearest to resources: arable, ore, cth, gis, minicomputer, hydropower, pastures, mccoy,
# Nearest to brother: son, sister, protectorate, violently, hecuba, sardinia, sentenced, eldest,
# Nearest to writers: novelists, barfield, comedians, playwrights, dykes, masterwork, dell, shiraz,
# Nearest to freedom: speech, laissez, blaming, grue, olimp, talionis, autographed, patrice,
# Nearest to derived: slovenian, perspectives, declension, ism, descends, imperfective, neu, prepositional,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 3.8984 0.3271 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 3.8872 0.2069 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 3.8862 0.3237 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 3.8473 0.3210 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 3.8707 0.3253 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 3.8483 0.3261 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 3.8654 0.3198 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 3.8070 0.3116 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 3.8488 0.3113 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 3.8813 0.3117 sec/batch
# Nearest to his: tombstone, he, jehoshaphat, spent, himself, pepys, guthrum, was,
# Nearest to history: transcends, combinatorics, summarized, astronautica, eds, tver, exacting, runciman,
# Nearest to by: takings, shortly, the, sikh, retaliated, obeying, had, bem,
# Nearest to up: pechenegs, davidian, quebecois, speeds, crafting, sebasti, across, healthy,
# Nearest to all: honda, genealogies, overlap, are, approximates, and, chakras, beyond,
# Nearest to during: period, era, hajj, late, ionization, venosus, throughout, lasted,
# Nearest to used: use, thalweg, drugs, names, discretization, uses, amharic, aspires,
# Nearest to from: localized, communally, michelob, peril, fictitious, galileo, pitman, children,
# Nearest to quite: surinam, huey, visor, iru, antoninianus, stressed, relevance, hz,
# Nearest to proposed: withhold, amendment, divest, ridgway, koruna, rider, nigerian, principal,
# Nearest to scale: notes, scales, tonality, traction, chromatic, tuning, tempered, chernenko,
# Nearest to resources: arable, ore, cth, gis, minicomputer, hydropower, pastures, mccoy,
# Nearest to brother: son, violently, protectorate, sister, sentenced, hecuba, sardinia, cousin,
# Nearest to writers: novelists, barfield, comedians, playwrights, shiraz, dykes, masterwork, handsomest,
# Nearest to freedom: speech, blaming, laissez, grue, patrice, autographed, gardiner, talionis,
# Nearest to derived: imperfective, descends, ism, perspectives, slovenian, declension, word, prepositional,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 3.8500 0.3168 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 3.8788 0.3284 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 3.7468 0.3335 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 3.8173 0.3203 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 3.7746 0.3497 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 3.7742 0.4318 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 3.8460 0.4238 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 3.8734 0.4511 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 3.8183 0.3741 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 3.8528 0.3737 sec/batch
# Nearest to his: tombstone, he, jehoshaphat, spent, himself, guthrum, fascinated, met,
# Nearest to history: transcends, summarized, combinatorics, astronautica, reads, workstation, external, eds,
# Nearest to by: camshaft, takings, obeying, the, trusteeship, editable, sikh, shortly,
# Nearest to up: crafting, davidian, pechenegs, quebecois, speeds, healthy, flip, across,
# Nearest to all: honda, are, will, directs, and, genealogies, overlap, beyond,
# Nearest to during: period, era, hajj, ionization, spread, badges, venosus, late,
# Nearest to used: use, names, drugs, discretization, often, thalweg, oscilloscopes, other,
# Nearest to from: localized, michelob, fictitious, communally, peril, pitman, children, galileo,
# Nearest to quite: surinam, huey, relevance, drugged, stressed, visor, ile, hz,
# Nearest to proposed: amendment, withhold, principal, divest, ridgway, rider, martinus, model,
# Nearest to scale: notes, scales, tempered, chernenko, tonality, traction, possibilities, chromatic,
# Nearest to resources: arable, ore, cth, gis, minicomputer, vegetarianism, mccoy, instructions,
# Nearest to brother: son, sister, protectorate, violently, sardinia, hecuba, sentenced, clement,
# Nearest to writers: novelists, barfield, comedians, playwrights, shiraz, dykes, winners, dell,
# Nearest to freedom: speech, laissez, blaming, talionis, patrice, grue, gardiner, autographed,
# Nearest to derived: declension, imperfective, ism, word, slovenian, perspectives, descends, prepositional,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 3.8967 0.3732 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 3.8120 0.3662 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 3.8118 0.3668 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 3.8482 0.3670 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 3.8397 0.3696 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 3.8361 0.3666 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 3.8665 0.3686 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 3.8585 0.3683 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 3.8119 0.3680 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 3.8798 0.3678 sec/batch
# Nearest to his: tombstone, he, spent, himself, met, s, curia, cohomology,
# Nearest to history: combinatorics, eds, external, transcends, summarized, historical, astronautica, tver,
# Nearest to by: the, camshaft, editable, shortly, grossly, obeying, takings, of,
# Nearest to up: davidian, sebasti, crafting, speeds, quebecois, across, pechenegs, flip,
# Nearest to all: are, honda, overlap, leq, will, and, approximates, genealogies,
# Nearest to during: period, era, ionization, badges, throughout, late, hajj, spread,
# Nearest to used: use, often, thalweg, names, discretization, drugs, aspires, are,
# Nearest to from: localized, galileo, michelob, fictitious, peril, communally, acclaimed, obtains,
# Nearest to quite: surinam, huey, relevance, iru, drugged, antoninianus, stressed, ile,
# Nearest to proposed: withhold, amendment, principal, mayer, divest, ridgway, model, reconstructions,
# Nearest to scale: scales, notes, tempered, tonality, traction, perceived, chernenko, possibilities,
# Nearest to resources: arable, ore, gis, cth, minicomputer, vegetarianism, mccoy, transhumanism,
# Nearest to brother: son, sister, protectorate, violently, hecuba, sardinia, clement, eldest,
# Nearest to writers: novelists, comedians, barfield, playwrights, shiraz, existentialism, dykes, masterwork,
# Nearest to freedom: speech, blaming, laissez, talionis, autographed, grue, olimp, gardiner,
# Nearest to derived: ism, word, perspectives, imperfective, declension, slovenian, catecholamines, whorf,
# Epoch 6/10 Iteration: 26100 Avg. Training loss: 3.8621 0.3709 sec/batch
# Epoch 6/10 Iteration: 26200 Avg. Training loss: 3.8361 0.3677 sec/batch
# Epoch 6/10 Iteration: 26300 Avg. Training loss: 3.8429 0.3709 sec/batch
# Epoch 6/10 Iteration: 26400 Avg. Training loss: 3.8283 0.3670 sec/batch
# Epoch 6/10 Iteration: 26500 Avg. Training loss: 3.8185 0.3701 sec/batch
# Epoch 6/10 Iteration: 26600 Avg. Training loss: 3.8740 0.3698 sec/batch
# Epoch 6/10 Iteration: 26700 Avg. Training loss: 3.8110 0.3909 sec/batch
# Epoch 6/10 Iteration: 26800 Avg. Training loss: 3.9363 0.3952 sec/batch
# Epoch 6/10 Iteration: 26900 Avg. Training loss: 3.9049 0.3823 sec/batch
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 3.8729 0.3596 sec/batch
# Nearest to his: tombstone, he, spent, s, himself, spends, worked, moire,
# Nearest to history: external, eds, summarized, combinatorics, strategic, penn, tver, workstation,
# Nearest to by: the, of, shortly, sikh, had, takings, trusteeship, fording,
# Nearest to up: davidian, woolf, quebecois, pechenegs, crafting, across, sebasti, rapp,
# Nearest to all: honda, are, overlap, genealogies, megalopolis, and, directs, will,
# Nearest to during: period, era, was, throughout, hajj, the, late, lasted,
# Nearest to used: use, names, discretization, often, drugs, uses, aspires, oscilloscopes,
# Nearest to from: localized, acclaimed, peril, jenny, michelob, communally, fictitious, children,
# Nearest to quite: surinam, huey, relevance, antoninianus, iru, ile, drugged, congregationalist,
# Nearest to proposed: withhold, amendment, ridgway, principal, divest, mayer, koruna, resolve,
# Nearest to scale: notes, scales, tempered, chromatic, tonality, tuning, traction, chernenko,
# Nearest to resources: arable, ore, gis, cth, minicomputer, mccoy, pastures, transhumanism,
# Nearest to brother: son, sister, protectorate, clement, eldest, hecuba, violently, cousin,
# Nearest to writers: novelists, comedians, barfield, winners, playwrights, dykes, polymaths, satirists,
# Nearest to freedom: speech, blaming, autographed, talionis, laissez, grue, patrice, olimp,
# Nearest to derived: ism, perspectives, word, declension, imperfective, whorf, catecholamines, prepositional,

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
