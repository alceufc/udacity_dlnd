# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
print("Total words: {}".format(len(train_words)))
print("We selected {:.2f}% of the words.".format(100.0*len(train_words)/len(words)))
print("Unique words: {}".format(len(set(train_words))))
# Out:
# Total words: 4629843
# We selected 27.76% of the words.
# Unique words: 63641

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6485 0.2704 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6129 0.2689 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5460 0.2683 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6108 0.2686 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4822 0.2696 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5500 0.2699 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6014 0.2689 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5464 0.2716 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4722 0.2694 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4397 0.2686 sec/batch
# Nearest to united: disco, historiographical, celt, painda, trinidad, commissars, unexploited, spurs,
# Nearest to had: conant, markets, neighbourhood, mechanic, tres, guin, woodpecker, haznawi,
# Nearest to people: mcmurdo, retain, hardwired, rl, refuge, mailing, midday, orientational,
# Nearest to most: seaboard, centime, sumptuous, leaven, rampling, physicists, wobegon, dasyprocta,
# Nearest to at: conformance, knott, decennial, hedeby, merina, shawn, seaport, radium,
# Nearest to can: fatal, nsaids, devises, weird, ramakrishna, stringed, tailless, moroccans,
# Nearest to have: eider, jeu, spur, brutus, oxbridge, spouse, pump, airways,
# Nearest to also: costa, pembroke, italians, urges, chifley, electrolyte, maxell, jvm,
# Nearest to freedom: helsingborg, rylands, newcomen, splintered, cultural, analyzing, burgesses, lawyers,
# Nearest to articles: waco, origins, satisfy, own, ferrell, nmd, smack, epistemic,
# Nearest to experience: britain, aspartate, collated, fewest, transfers, phil, hashish, juries,
# Nearest to pope: fervent, adria, hispaniola, rites, amazing, deluise, comintern, cdm,
# Nearest to behind: puf, euskal, vaduz, guns, infraction, lovejoy, darin, divisions,
# Nearest to liberal: troy, washed, reconstructed, categorised, attitude, power, houston, tagus,
# Nearest to engine: only, its, mcleod, cosmology, photograph, piercy, hypomanic, bethesda,
# Nearest to writers: rufus, acura, alamos, blackboard, wrist, amid, surfaced, no,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4478 0.2734 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3983 0.2690 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3233 0.2678 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2359 0.2701 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1770 0.2714 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1520 0.2675 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1151 0.2692 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0561 0.2687 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0029 0.2704 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9787 0.2698 sec/batch
# Nearest to united: disco, many, construction, historiographical, celt, wombat, telecommunications, spurs,
# Nearest to had: neighbourhood, markets, mechanic, processes, bus, nevertheless, conant, commander,
# Nearest to people: retain, mcmurdo, widespread, size, midday, normative, arguably, refuge,
# Nearest to most: seaboard, paid, india, physicists, opportunities, sumptuous, centime, re,
# Nearest to at: conformance, even, herself, culture, merina, decennial, table, radium,
# Nearest to can: fatal, range, step, weird, places, ferdinand, stringed, units,
# Nearest to have: spur, clarity, pump, chip, eider, real, brutus, airways,
# Nearest to also: italians, pembroke, using, costa, maxell, compatible, chifley, conditional,
# Nearest to freedom: lawyers, cultural, newcomen, splintered, plantations, analyzing, speedy, rylands,
# Nearest to articles: own, origins, satisfy, waco, week, kids, heyday, manufacturing,
# Nearest to experience: britain, transfers, noted, documentary, phil, global, fewest, awacs,
# Nearest to pope: fervent, hispaniola, rites, adria, away, cdm, very, prosperity,
# Nearest to behind: guns, divisions, ice, euskal, puf, paramilitary, averell, cbc,
# Nearest to liberal: power, reconstructed, troy, washed, attitude, forms, orientalist, houston,
# Nearest to engine: only, its, restrict, photograph, metropolis, even, summation, encompassing,
# Nearest to writers: rufus, no, acura, alamos, blackboard, wrist, surfaced, databases,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9362 0.2721 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9004 0.2679 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8664 0.2688 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8465 0.2689 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7982 0.2671 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8221 0.2686 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7826 0.2703 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7795 0.2698 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7802 0.2688 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7754 0.2703 sec/batch
# Nearest to united: disco, historiographical, spurs, many, unstable, peaks, tasmania, slovenia,
# Nearest to had: conant, neighbourhood, markets, fledgling, bus, transshipment, militaries, mechanic,
# Nearest to people: mcmurdo, retain, refuge, midday, mailing, normative, widespread, tertullian,
# Nearest to most: seaboard, physicists, romanian, opportunities, delegations, rampling, seconds, sumptuous,
# Nearest to at: conformance, even, knott, brutal, favorable, scoreless, shawn, radium,
# Nearest to can: fatal, range, stringed, theorized, weird, step, array, places,
# Nearest to have: spur, eider, spouse, brutus, pump, clarity, striking, airways,
# Nearest to also: costa, italians, pembroke, bounds, maxell, conditional, chifley, jvm,
# Nearest to freedom: cultural, newcomen, lawyers, splintered, plantations, helsingborg, analyzing, spreads,
# Nearest to articles: waco, satisfy, own, manufacturing, week, origins, kids, repeating,
# Nearest to experience: britain, transfers, awacs, phil, noted, fewest, documentary, aspartate,
# Nearest to pope: fervent, rites, hispaniola, away, prosperity, cdm, adria, amazing,
# Nearest to behind: guns, divisions, paramilitary, euskal, puf, ice, middlesex, averell,
# Nearest to liberal: power, troy, reconstructed, houston, attitude, washed, orientalist, baker,
# Nearest to engine: only, its, restrict, cosmology, summation, photograph, fired, swings,
# Nearest to writers: rufus, alamos, acura, wrist, surfaced, no, blackboard, mecca,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7998 0.2749 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7436 0.2692 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7304 0.2678 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6988 0.2691 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7571 0.2699 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7101 0.2705 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6972 0.2693 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7296 0.2683 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7116 0.2685 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6558 0.2680 sec/batch
# Nearest to united: disco, historiographical, babylon, nagai, slovenia, spurs, bilateral, peaks,
# Nearest to had: handing, commander, transshipment, fledgling, militaries, conant, woodpecker, neighbourhood,
# Nearest to people: mcmurdo, retain, midday, refuge, hardwired, widespread, tertullian, athletics,
# Nearest to most: seaboard, delegations, romanian, rampling, accomplishes, india, physicists, leaven,
# Nearest to at: conformance, knott, scoreless, brutal, problematic, subservient, directionally, patent,
# Nearest to can: range, fatal, stringed, generator, chelating, theorized, array, weird,
# Nearest to have: eider, spur, spouse, pump, clarity, brutus, striking, stream,
# Nearest to also: costa, pembroke, jvm, conditional, italians, urges, maxell, chifley,
# Nearest to freedom: cultural, newcomen, helsingborg, lawyers, burgesses, plantations, splintered, hendrix,
# Nearest to articles: waco, satisfy, manufacturing, origins, barbaric, own, week, epistemic,
# Nearest to experience: britain, transfers, hashish, aspartate, fewest, awacs, noted, phil,
# Nearest to pope: fervent, rites, prosperity, away, hispaniola, cdm, adria, petherbridge,
# Nearest to behind: puf, guns, paramilitary, euskal, divisions, ice, cbc, averell,
# Nearest to liberal: power, troy, houston, reconstructed, washed, evolution, donald, orientalist,
# Nearest to engine: only, its, restrict, swings, summation, bethesda, photograph, cosmology,
# Nearest to writers: alamos, rufus, acura, surfaced, mecca, blackboard, esq, wrist,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6750 0.2699 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6407 0.2716 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6305 0.2692 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6415 0.2687 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6340 0.2732 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6485 0.2736 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6063 0.1942 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5501 0.2735 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5570 0.2732 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4832 0.2782 sec/batch
# Nearest to united: historiographical, disco, babylon, slovenia, nagai, tasmania, iraq, peaks,
# Nearest to had: handing, fledgling, woodpecker, conant, commander, transshipment, probus, militaries,
# Nearest to people: mcmurdo, retain, refuge, widespread, hardwired, midday, tertullian, smoothly,
# Nearest to most: delegations, seaboard, rampling, romanian, sumptuous, leaven, accomplishes, communion,
# Nearest to at: knott, conformance, scoreless, directionally, subservient, patent, ruined, shawn,
# Nearest to can: range, array, stringed, chelating, fatal, generator, transform, theorized,
# Nearest to have: eider, pump, spur, clarity, spouse, floral, advise, airways,
# Nearest to also: pembroke, costa, jvm, maxell, italians, chifley, conditional, urges,
# Nearest to freedom: cultural, newcomen, helsingborg, lawyers, splintered, burgesses, harrisburg, hendrix,
# Nearest to articles: waco, barbaric, origins, manufacturing, satisfy, inaccuracies, week, own,
# Nearest to experience: hashish, aspartate, britain, transfers, awacs, fewest, handball, remarried,
# Nearest to pope: fervent, rites, prosperity, away, adria, hispaniola, cdm, petherbridge,
# Nearest to behind: puf, euskal, guns, paramilitary, ice, middlesex, lovejoy, averell,
# Nearest to liberal: power, houston, troy, reconstructed, hdi, donald, washed, realisation,
# Nearest to engine: only, its, fuel, summation, swings, bethesda, bit, restrict,
# Nearest to writers: rufus, alamos, acura, surfaced, mecca, esq, blackboard, kur,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4956 0.2768 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4890 0.2684 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4640 0.2702 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5122 0.2729 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4950 0.2696 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4825 0.2742 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4707 0.2712 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4025 0.2726 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4266 0.2697 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4185 0.2680 sec/batch
# Nearest to united: historiographical, slovenia, disco, babylon, bilateral, tasmania, exercised, iraq,
# Nearest to had: handing, fledgling, probus, commander, siding, conant, woodpecker, bus,
# Nearest to people: mcmurdo, retain, refuge, hardwired, midday, widespread, tertullian, millwall,
# Nearest to most: delegations, rampling, india, seaboard, leaven, installing, accomplishes, romanian,
# Nearest to at: knott, ruined, conformance, shawn, darren, problematic, subservient, ragged,
# Nearest to can: array, fatal, range, generator, chelating, uniformity, stringed, transform,
# Nearest to have: pump, eider, clarity, varies, pagerank, spouse, spur, floral,
# Nearest to also: jvm, maxell, costa, pembroke, urges, conditional, chifley, italians,
# Nearest to freedom: cultural, newcomen, helsingborg, lawyers, hendrix, splintered, burgesses, harrisburg,
# Nearest to articles: waco, manufacturing, barbaric, origins, satisfy, oed, inaccuracies, goering,
# Nearest to experience: aspartate, hashish, transfers, britain, awacs, fewest, handball, polyethylene,
# Nearest to pope: fervent, rites, away, prosperity, adria, england, hispaniola, petherbridge,
# Nearest to behind: puf, euskal, ice, infraction, middlesex, cbc, vaduz, it,
# Nearest to liberal: power, houston, troy, realisation, disseminating, vivax, cortland, bitches,
# Nearest to engine: only, fuel, bit, summation, its, perpendicular, bethesda, cosmology,
# Nearest to writers: rufus, acura, alamos, surfaced, esq, mecca, kur, wrist,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4598 0.2734 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4166 0.2719 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4571 0.2709 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4142 0.2701 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4285 0.2746 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4557 0.2732 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3955 0.2854 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3881 0.2702 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4217 0.2765 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3827 0.2741 sec/batch
# Nearest to united: bilateral, historiographical, states, slovenia, tasmania, babylon, spiteful, disco,
# Nearest to had: handing, fledgling, commander, probus, siding, woodpecker, conant, ascertained,
# Nearest to people: mcmurdo, retain, refuge, hardwired, widespread, millwall, opt, evinced,
# Nearest to most: delegations, rampling, accomplishes, india, seaboard, leaven, installing, wobegon,
# Nearest to at: knott, darren, scoreless, directionally, shawn, ruined, collectivized, subservient,
# Nearest to can: array, generator, fatal, transform, chelating, range, step, applied,
# Nearest to have: spouse, pump, eider, floral, scars, pagerank, conquistadors, brutus,
# Nearest to also: jvm, costa, maxell, urges, sprint, cardiology, unsolvable, conditional,
# Nearest to freedom: cultural, helsingborg, newcomen, lawyers, harrisburg, burgesses, splintered, hendrix,
# Nearest to articles: waco, barbaric, manufacturing, origins, barometric, freshness, arrestor, inaccuracies,
# Nearest to experience: hashish, aspartate, goodness, transfers, polyethylene, collated, handball, fewest,
# Nearest to pope: rites, fervent, prosperity, adria, petherbridge, hispaniola, away, england,
# Nearest to behind: puf, euskal, ice, middlesex, pyrolytic, vaduz, infraction, guns,
# Nearest to liberal: power, cortland, views, propose, realisation, houston, vivax, bitches,
# Nearest to engine: fuel, perpendicular, only, bit, summation, injection, amp, bethesda,
# Nearest to writers: rufus, acura, alamos, surfaced, esq, kur, russel, mecca,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3704 0.2934 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3847 0.2761 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3604 0.2710 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3657 0.2732 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3816 0.2778 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3851 0.2767 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3714 0.2711 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3941 0.2747 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3112 0.2774 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3352 0.2716 sec/batch
# Nearest to united: bilateral, states, historiographical, exercised, spiteful, tasmania, jurisdiction, homecoming,
# Nearest to had: handing, commander, fledgling, probus, ascertained, suppressed, siding, chapin,
# Nearest to people: mcmurdo, refuge, retain, widespread, hardwired, evinced, opt, midday,
# Nearest to most: delegations, india, seaboard, rampling, wobegon, accomplishes, arcane, leaven,
# Nearest to at: knott, numeration, shawn, subservient, ruined, problematic, scoreless, ragged,
# Nearest to can: array, fatal, generator, chelating, transform, stringed, range, uniformity,
# Nearest to have: spouse, pagerank, clarity, scars, conquistadors, floral, pump, eider,
# Nearest to also: jvm, costa, maxell, conditional, unsolvable, anniversaries, urges, sprint,
# Nearest to freedom: cultural, helsingborg, lawyers, newcomen, burgesses, harrisburg, hendrix, ftc,
# Nearest to articles: waco, barbaric, published, acronym, origins, barometric, computing, freshness,
# Nearest to experience: hashish, aspartate, polyethylene, goodness, britain, remarried, transfers, fewest,
# Nearest to pope: rites, fervent, prosperity, away, petherbridge, adria, hispaniola, masterpieces,
# Nearest to behind: puf, euskal, middlesex, pyrolytic, punk, infraction, averell, marginalism,
# Nearest to liberal: power, cortland, realisation, propose, views, houston, vivax, muses,
# Nearest to engine: fuel, perpendicular, injection, bit, only, summation, bethesda, outboard,
# Nearest to writers: rufus, alamos, esq, mecca, schleicher, acura, peerages, surfaced,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3396 0.2756 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3101 0.2751 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3631 0.2733 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3960 0.2734 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3700 0.2735 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3044 0.2719 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3232 0.2765 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3583 0.2692 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2202 0.2725 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2969 0.2729 sec/batch
# Nearest to united: states, bilateral, historiographical, homecoming, spiteful, tasmania, exercised, commissars,
# Nearest to had: handing, fledgling, ascertained, woodpecker, probus, lupercalia, generosity, commander,
# Nearest to people: mcmurdo, refuge, midday, widespread, opt, hardwired, evinced, closeted,
# Nearest to most: delegations, india, rampling, accomplishes, wobegon, arcane, clutching, friendliness,
# Nearest to at: knott, shawn, ruined, numeration, darren, brisance, bcnf, scoreless,
# Nearest to can: array, generator, fatal, chelating, transform, range, devises, stringed,
# Nearest to have: spouse, conquistadors, pagerank, scars, floral, zwicker, clarity, doubt,
# Nearest to also: costa, jvm, maxell, unsolvable, urges, cardiology, anniversaries, sound,
# Nearest to freedom: cultural, lawyers, helsingborg, harrisburg, burgesses, newcomen, hendrix, ftc,
# Nearest to articles: waco, published, barbaric, origins, barometric, acronym, teamsters, freshness,
# Nearest to experience: aspartate, hashish, goodness, polyethylene, remarried, collated, fewest, trifle,
# Nearest to pope: rites, fervent, petherbridge, adria, masterpieces, hispaniola, away, morecambe,
# Nearest to behind: puf, euskal, titles, middlesex, it, pyrolytic, vaduz, score,
# Nearest to liberal: power, realisation, cortland, propose, views, houston, naturalizing, vivax,
# Nearest to engine: fuel, injection, outboard, photograph, perpendicular, bit, its, fired,
# Nearest to writers: rufus, alamos, esq, schleicher, peerages, mecca, hoffmann, kur,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2954 0.2758 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3186 0.2768 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3710 0.1152 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2550 0.2754 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2363 0.2726 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2132 0.2809 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2575 0.2693 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2094 0.2726 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2324 0.2749 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2097 0.2759 sec/batch
# Nearest to united: states, historiographical, bilateral, homecoming, tasmania, spiteful, disco, commissars,
# Nearest to had: handing, probus, ascertained, fledgling, generosity, were, lupercalia, commander,
# Nearest to people: mcmurdo, refuge, opt, midday, widespread, mothman, closeted, theorists,
# Nearest to most: delegations, india, rampling, wobegon, arcane, accomplishes, peking, clutching,
# Nearest to at: knott, shawn, ruined, brisance, ragged, numeration, bcnf, darren,
# Nearest to can: fatal, array, generator, chelating, transform, range, perceptible, moroccans,
# Nearest to have: spouse, conquistadors, pagerank, chimpanzee, clarity, pump, striking, floral,
# Nearest to also: jvm, maxell, costa, unsolvable, italians, cardiology, decimalisation, anniversaries,
# Nearest to freedom: cultural, helsingborg, lawyers, hendrix, newcomen, burgesses, ftc, harrisburg,
# Nearest to articles: waco, published, origins, barbaric, computing, barometric, freshness, epistemic,
# Nearest to experience: aspartate, hashish, goodness, polyethylene, fewest, noted, awacs, remarried,
# Nearest to pope: rites, fervent, petherbridge, masterpieces, adria, rer, england, xv,
# Nearest to behind: puf, score, pyrolytic, euskal, titles, it, infraction, vaduz,
# Nearest to liberal: power, realisation, views, propose, cortland, applied, meanwhile, muses,
# Nearest to engine: fuel, outboard, injection, photograph, kits, its, lauder, only,
# Nearest to writers: rufus, schleicher, esq, alamos, peerages, hoffmann, mecca, russel,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2485 0.2744 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2260 0.2714 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2464 0.2749 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1132 0.2909 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1837 0.2713 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1628 0.2698 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1783 0.2668 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1773 0.2868 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2058 0.2729 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1509 0.2764 sec/batch
# Nearest to united: states, bilateral, historiographical, homecoming, spiteful, telecommunications, tasmania, commissars,
# Nearest to had: handing, were, ascertained, probus, conant, lupercalia, generosity, commander,
# Nearest to people: mcmurdo, refuge, midday, mothman, opt, widespread, fatalities, closeted,
# Nearest to most: delegations, india, rampling, wobegon, arcane, accomplishes, repurchase, clutching,
# Nearest to at: knott, shawn, ruined, brisance, problematic, numeration, ragged, dev,
# Nearest to can: array, fatal, generator, transform, chelating, uniformity, perceptible, devises,
# Nearest to have: spouse, pagerank, chimpanzee, conquistadors, floral, brutus, striking, zwicker,
# Nearest to also: costa, maxell, jvm, anniversaries, cardiology, sound, unsolvable, sprint,
# Nearest to freedom: cultural, lawyers, helsingborg, hendrix, burgesses, newcomen, ftc, harrisburg,
# Nearest to articles: published, waco, computing, origins, barbaric, sigplan, barometric, acronym,
# Nearest to experience: aspartate, goodness, hashish, polyethylene, noted, existential, fewest, collated,
# Nearest to pope: fervent, rites, away, masterpieces, petherbridge, adria, hispaniola, xv,
# Nearest to behind: puf, score, euskal, pyrolytic, middlesex, titles, it, infraction,
# Nearest to liberal: power, realisation, views, propose, cortland, democrat, applied, naturalizing,
# Nearest to engine: fuel, outboard, injection, photograph, kits, lauder, glockenspiel, fired,
# Nearest to writers: esq, schleicher, alamos, rufus, russel, peerages, hoffmann, noteworthy,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1787 0.2746 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2106 0.2741 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1656 0.2732 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1709 0.2695 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1836 0.2698 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1691 0.2744 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1904 0.2740 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1468 0.2684 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1335 0.2701 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1835 0.2708 sec/batch
# Nearest to united: states, bilateral, historiographical, spiteful, homecoming, tasmania, commissars, jurisdiction,
# Nearest to had: handing, conant, fledgling, generosity, were, lupercalia, commander, chapin,
# Nearest to people: mcmurdo, refuge, fatalities, opt, widespread, mothman, closeted, millwall,
# Nearest to most: delegations, india, wobegon, repurchase, rampling, enunciation, accomplishes, arcane,
# Nearest to at: shawn, knott, numeration, brisance, ruined, patent, dev, ragged,
# Nearest to can: array, fatal, generator, transform, scalars, devises, definiendum, basques,
# Nearest to have: spouse, pagerank, chimpanzee, conquistadors, floral, zwicker, originated, doubt,
# Nearest to also: costa, jvm, cardiology, maxell, unsolvable, sound, anniversaries, hs,
# Nearest to freedom: cultural, lawyers, helsingborg, ftc, restraint, hendrix, burgesses, newborns,
# Nearest to articles: waco, published, reviews, computing, epistemic, origins, april, barbaric,
# Nearest to experience: aspartate, goodness, hashish, remarried, noted, existential, fewest, refrains,
# Nearest to pope: fervent, rites, masterpieces, petherbridge, away, xv, adria, hispaniola,
# Nearest to behind: puf, score, it, middlesex, euskal, pyrolytic, titles, shooter,
# Nearest to liberal: power, realisation, views, cortland, propose, meanwhile, applied, candidates,
# Nearest to engine: fuel, outboard, injection, photograph, fired, lauder, glockenspiel, its,
# Nearest to writers: alamos, peerages, esq, noteworthy, hoffmann, russel, schleicher, rufus,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2001 0.2743 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1779 0.2708 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1818 0.2706 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2068 0.2718 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1382 0.2701 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1442 0.2692 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1767 0.2685 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1347 0.2723 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1837 0.2774 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2051 0.2867 sec/batch
# Nearest to united: states, historiographical, bilateral, homecoming, quisling, commissars, spiteful, jurisdiction,
# Nearest to had: generosity, were, handing, siding, lupercalia, probus, chapin, tsars,
# Nearest to people: refuge, mcmurdo, mothman, opt, fatalities, millwall, closeted, passos,
# Nearest to most: delegations, india, repurchase, wobegon, rampling, peking, accomplishes, arcane,
# Nearest to at: knott, shawn, ruined, numeration, gilgal, darren, brisance, contravening,
# Nearest to can: fatal, array, moroccans, perceptible, generator, definiendum, chelating, basques,
# Nearest to have: spouse, pagerank, conquistadors, zwicker, chimpanzee, originated, doubt, advise,
# Nearest to also: costa, jvm, anniversaries, pembroke, italians, cardiology, rastafari, sound,
# Nearest to freedom: cultural, lawyers, helsingborg, burgesses, ftc, restraint, harrisburg, hendrix,
# Nearest to articles: waco, published, barbaric, reviews, origins, acronym, april, computing,
# Nearest to experience: aspartate, hashish, goodness, remarried, refrains, headlines, trifle, noted,
# Nearest to pope: fervent, rites, masterpieces, xv, petherbridge, adria, away, franciscans,
# Nearest to behind: puf, score, middlesex, euskal, it, bloomfield, titles, pyrolytic,
# Nearest to liberal: power, realisation, cortland, views, applied, donald, meanwhile, narrowly,
# Nearest to engine: fuel, outboard, injection, piston, gasoline, pistons, photograph, diodes,
# Nearest to writers: alamos, peerages, noteworthy, esq, hoffmann, russel, schleicher, rufus,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2419 0.2828 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1487 0.2805 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1259 0.2782 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1363 0.2716 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0625 0.2721 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1438 0.2828 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1166 0.2738 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1420 0.2749 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1491 0.0374 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1122 0.2799 sec/batch
# Nearest to united: states, historiographical, homecoming, bilateral, commissars, tasmania, quisling, jurisdiction,
# Nearest to had: were, generosity, lupercalia, handing, siding, fledgling, tsars, chapin,
# Nearest to people: mcmurdo, opt, fatalities, refuge, mothman, closeted, passos, widespread,
# Nearest to most: india, delegations, repurchase, arcane, wobegon, enunciation, repressor, rampling,
# Nearest to at: shawn, knott, ruined, numeration, brisance, bcnf, gilgal, darren,
# Nearest to can: fatal, array, definiendum, moroccans, perceptible, chelating, transform, basques,
# Nearest to have: spouse, pagerank, conquistadors, chimpanzee, zwicker, originated, floral, doubt,
# Nearest to also: costa, jvm, italians, maxell, cardiology, anniversaries, hs, unsolvable,
# Nearest to freedom: cultural, lawyers, helsingborg, ftc, burgesses, restraint, hendrix, newborns,
# Nearest to articles: waco, published, april, reviews, computing, barbaric, sigplan, origins,
# Nearest to experience: aspartate, hashish, goodness, remarried, trifle, refrains, headlines, fewest,
# Nearest to pope: fervent, rites, xv, masterpieces, hatched, adria, bundesrat, petherbridge,
# Nearest to behind: puf, score, it, pyrolytic, fanbase, euskal, middlesex, bloomfield,
# Nearest to liberal: power, realisation, views, cortland, applied, marx, donald, propose,
# Nearest to engine: fuel, piston, injection, outboard, pistons, photograph, speed, engined,
# Nearest to writers: peerages, alamos, noteworthy, esq, hoffmann, russel, schleicher, fiction,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1065 0.2897 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.1017 0.2768 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0940 0.2699 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0652 0.2725 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0743 0.2737 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0496 0.2829 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0880 0.2737 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0940 0.2827 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1117 0.2875 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0479 0.2802 sec/batch
# Nearest to united: states, historiographical, homecoming, bilateral, commissars, tasmania, list, disco,
# Nearest to had: were, generosity, ascertained, handing, lupercalia, fledgling, probus, tsars,
# Nearest to people: fatalities, mcmurdo, opt, mothman, refuge, underlying, passos, widespread,
# Nearest to most: india, delegations, repurchase, wobegon, afghani, repressor, rampling, arcane,
# Nearest to at: shawn, knott, ruined, brisance, bcnf, the, problematic, numeration,
# Nearest to can: fatal, chelating, moroccans, array, perceptible, definiendum, nsaids, basques,
# Nearest to have: spouse, chimpanzee, conquistadors, pagerank, zwicker, floral, striking, originated,
# Nearest to also: costa, jvm, italians, is, maxell, anniversaries, cardiology, ddd,
# Nearest to freedom: cultural, lawyers, helsingborg, ftc, burgesses, camphor, restraint, hendrix,
# Nearest to articles: waco, published, barbaric, sigplan, april, origins, computing, overview,
# Nearest to experience: aspartate, hashish, goodness, remarried, refrains, headlines, reveal, profit,
# Nearest to pope: fervent, rites, xv, franciscans, masterpieces, adria, hatched, petherbridge,
# Nearest to behind: it, score, pyrolytic, puf, middlesex, bloomfield, fanbase, euskal,
# Nearest to liberal: power, realisation, cortland, views, narrowly, mohamed, disseminating, democrat,
# Nearest to engine: fuel, piston, outboard, injection, lauder, pistons, engined, ifv,
# Nearest to writers: peerages, esq, alamos, noteworthy, russel, anthem, schleicher, hoffmann,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0222 0.2843 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0154 0.2757 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0388 0.2733 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0575 0.2707 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0593 0.2736 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0908 0.2854 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0347 0.2770 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0994 0.2723 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.1017 0.2745 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0246 0.2729 sec/batch
# Nearest to united: states, historiographical, homecoming, bilateral, tasmania, list, trinidad, slovenia,
# Nearest to had: were, generosity, lupercalia, handing, fledgling, ascertained, tsars, probus,
# Nearest to people: fatalities, mcmurdo, passos, opt, refuge, underlying, mothman, midday,
# Nearest to most: delegations, india, repurchase, accomplishes, enunciation, opportunities, wobegon, repressor,
# Nearest to at: shawn, knott, ruined, numeration, bcnf, gilgal, the, contravening,
# Nearest to can: definiendum, array, perceptible, chelating, moroccans, fatal, subluxation, scalars,
# Nearest to have: spouse, chimpanzee, pagerank, striking, originated, zwicker, conquistadors, singled,
# Nearest to also: italians, costa, jvm, anniversaries, maxell, cardiology, electrolyte, is,
# Nearest to freedom: cultural, lawyers, ftc, helsingborg, burgesses, camphor, newborns, restraint,
# Nearest to articles: published, waco, reviews, sigplan, origins, barbaric, overview, oed,
# Nearest to experience: aspartate, goodness, hashish, existential, reveal, refrains, psychological, congestive,
# Nearest to pope: fervent, rites, franciscans, xv, masterpieces, hatched, adria, schelling,
# Nearest to behind: score, puf, pyrolytic, middlesex, euskal, fanbase, it, bloomfield,
# Nearest to liberal: power, views, realisation, cortland, mohamed, disseminating, attitude, kicker,
# Nearest to engine: fuel, piston, injection, outboard, gasoline, pistons, lauder, photograph,
# Nearest to writers: alamos, peerages, esq, russel, noteworthy, fiction, schleicher, anthem,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0701 0.2728 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1126 0.2698 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0377 0.2720 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0533 0.2728 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0763 0.2716 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0170 0.2788 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0526 0.2710 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0320 0.2705 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0903 0.2777 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0335 0.2721 sec/batch
# Nearest to united: states, historiographical, homecoming, commissars, bilateral, jurisdiction, quisling, justices,
# Nearest to had: were, generosity, lupercalia, tsars, handing, ascertained, probus, his,
# Nearest to people: fatalities, passos, mcmurdo, opt, refuge, mothman, underlying, millwall,
# Nearest to most: delegations, india, repurchase, champions, accomplishes, welt, afghani, whitaker,
# Nearest to at: shawn, knott, ruined, gilgal, contravening, the, numeration, brisance,
# Nearest to can: definiendum, array, perceptible, moroccans, fatal, chelating, subluxation, sanitization,
# Nearest to have: spouse, chimpanzee, pagerank, brutus, conquistadors, originated, zwicker, doubt,
# Nearest to also: costa, italians, anniversaries, jvm, maxell, rastafari, hs, is,
# Nearest to freedom: cultural, lawyers, ftc, helsingborg, euroscepticism, splintered, burgesses, newborns,
# Nearest to articles: waco, published, reviews, overview, barbaric, sigplan, website, information,
# Nearest to experience: aspartate, hashish, existential, remarried, goodness, trifle, noted, refrains,
# Nearest to pope: fervent, rites, franciscans, xv, away, archbishops, masterpieces, adria,
# Nearest to behind: puf, middlesex, refugee, it, score, euskal, pyrolytic, fanbase,
# Nearest to liberal: power, views, realisation, cortland, mohamed, disseminating, houston, progressive,
# Nearest to engine: fuel, piston, outboard, injection, lauder, gasoline, lbf, engined,
# Nearest to writers: alamos, peerages, esq, noteworthy, fiction, russel, anthem, voss,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0584 0.2830 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0163 0.2698 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0176 0.2767 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0733 0.2825 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0301 0.2712 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1396 0.2732 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1227 0.2810 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0305 0.2744 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0252 0.2738 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0419 0.2698 sec/batch
# Nearest to united: states, historiographical, homecoming, bilateral, informers, commissars, justices, jurisdiction,
# Nearest to had: generosity, were, lupercalia, handing, tsars, ascertained, chapin, woodpecker,
# Nearest to people: fatalities, mcmurdo, opt, theorists, passos, refuge, underlying, closeted,
# Nearest to most: delegations, india, repurchase, accomplishes, arcane, polls, though, champions,
# Nearest to at: shawn, knott, ruined, gilgal, brisance, the, notables, ren,
# Nearest to can: definiendum, perceptible, array, moroccans, chelating, sanitization, subluxation, swede,
# Nearest to have: spouse, chimpanzee, originated, pagerank, conquistadors, zwicker, doubt, ena,
# Nearest to also: italians, anniversaries, costa, jvm, maxell, rastafari, is, hs,
# Nearest to freedom: cultural, lawyers, ftc, helsingborg, splintered, newborns, camphor, euroscepticism,
# Nearest to articles: waco, published, barbaric, april, reviews, overview, sigplan, freshness,
# Nearest to experience: hashish, aspartate, remarried, misgivings, refrains, reveal, ergosphere, trifle,
# Nearest to pope: rites, fervent, xv, franciscans, papal, hatched, adria, archbishops,
# Nearest to behind: puf, score, refugee, middlesex, bloomfield, it, fanbase, euskal,
# Nearest to liberal: views, power, progressive, cortland, realisation, houston, donald, attitude,
# Nearest to engine: fuel, piston, outboard, injection, gasoline, engined, lauder, pistons,
# Nearest to writers: alamos, esq, peerages, fiction, noteworthy, award, hosni, russel,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0404 0.2758 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0184 0.2725 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0341 0.2724 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0444 0.2718 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0827 0.2712 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0498 0.2297 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0085 0.2748 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9903 0.2755 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0119 0.2764 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9757 0.2708 sec/batch
# Nearest to united: states, historiographical, homecoming, bilateral, informers, commissars, tasmania, slovenia,
# Nearest to had: were, generosity, ascertained, his, lupercalia, was, handing, probus,
# Nearest to people: fatalities, mcmurdo, opt, underlying, passos, theorists, closeted, coincidences,
# Nearest to most: delegations, india, repurchase, enunciation, arcane, burgeoning, welt, champions,
# Nearest to at: shawn, knott, ruined, gilgal, the, brisance, sanctuary, ren,
# Nearest to can: moroccans, definiendum, perceptible, fatal, chelating, nabla, sanitization, array,
# Nearest to have: spouse, originated, chimpanzee, striking, pagerank, conquistadors, zwicker, doubt,
# Nearest to also: italians, anniversaries, is, costa, rastafari, jvm, cardiology, maxell,
# Nearest to freedom: cultural, lawyers, helsingborg, ftc, newborns, camphor, splintered, newcomen,
# Nearest to articles: waco, april, barbaric, reviews, published, freshness, sigplan, kimberley,
# Nearest to experience: aspartate, hashish, reveal, misgivings, existential, ergosphere, refrains, remarried,
# Nearest to pope: xv, fervent, rites, franciscans, pius, hatched, papal, adria,
# Nearest to behind: score, pyrolytic, refugee, puf, tsuka, bloomfield, fanbase, middlesex,
# Nearest to liberal: views, cortland, power, houston, progressive, realisation, donald, attitude,
# Nearest to engine: fuel, piston, outboard, lauder, engined, injection, lbf, prototypes,
# Nearest to writers: esq, alamos, peerages, noteworthy, hosni, fiction, persecutions, anthem,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9822 0.2761 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9460 0.2762 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0250 0.2728 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0223 0.2837 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0209 0.2958 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0158 0.2749 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9163 0.2746 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9726 0.2812 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9714 0.2688 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9896 0.2757 sec/batch
# Nearest to united: states, homecoming, bilateral, jurisdiction, historiographical, justices, south, tasmania,
# Nearest to had: were, generosity, ascertained, handing, probus, his, was, tsars,
# Nearest to people: fatalities, mcmurdo, opt, passos, underlying, midday, caucasian, refuge,
# Nearest to most: delegations, india, repurchase, champions, religous, there, though, burgeoning,
# Nearest to at: shawn, the, knott, ruined, brisance, sanctuary, offered, numeration,
# Nearest to can: definiendum, moroccans, chelating, sanitization, array, subluxation, perceptible, fatal,
# Nearest to have: spouse, originated, chimpanzee, striking, pagerank, doubt, conquistadors, singled,
# Nearest to also: is, italians, anniversaries, other, costa, maxell, electrolyte, ddd,
# Nearest to freedom: cultural, helsingborg, ftc, lawyers, camphor, splintered, newborns, warburg,
# Nearest to articles: barbaric, waco, published, reviews, sigplan, april, xinhua, freshness,
# Nearest to experience: aspartate, hashish, reveal, existential, ergosphere, refrains, fewest, misgivings,
# Nearest to pope: fervent, xv, franciscans, rites, papal, adria, calvi, hatched,
# Nearest to behind: score, refugee, pyrolytic, bloomfield, tsuka, middlesex, fanbase, booed,
# Nearest to liberal: power, democrat, progressive, mohamed, houston, donald, views, cortland,
# Nearest to engine: fuel, piston, outboard, lauder, injection, engined, lbf, amp,
# Nearest to writers: esq, alamos, peerages, hosni, noteworthy, persecutions, fiction, anthem,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9830 0.2758 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0139 0.2775 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9733 0.2716 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0018 0.2681 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0295 0.2717 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9754 0.2725 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9820 0.2701 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9901 0.2822 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9970 0.2790 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0036 0.2771 sec/batch
# Nearest to united: states, justices, homecoming, historiographical, navy, bilateral, commissars, south,
# Nearest to had: were, generosity, ascertained, handing, his, tsars, lupercalia, chapin,
# Nearest to people: fatalities, mcmurdo, opt, passos, underlying, caucasian, azawakh, refuge,
# Nearest to most: delegations, repurchase, polls, champions, india, though, enunciation, welt,
# Nearest to at: shawn, knott, the, ruined, navigators, foci, sanctuary, gilgal,
# Nearest to can: definiendum, subluxation, perceptible, nabla, hyperreal, swede, sanitization, moroccans,
# Nearest to have: spouse, originated, chimpanzee, doubt, singled, striking, ena, zwicker,
# Nearest to also: italians, anniversaries, cardiology, is, rastafari, electrolyte, a, ddd,
# Nearest to freedom: cultural, helsingborg, ftc, lawyers, splintered, camphor, euroscepticism, warburg,
# Nearest to articles: barbaric, waco, reviews, april, freshness, xinhua, nmd, published,
# Nearest to experience: reveal, existential, hashish, aspartate, misgivings, exit, ergosphere, fewest,
# Nearest to pope: xv, fervent, rites, franciscans, papal, gregory, pius, hatched,
# Nearest to behind: score, refugee, pyrolytic, bloomfield, middlesex, tsuka, overstepped, booed,
# Nearest to liberal: progressive, cortland, power, democrat, houston, views, mohamed, narrowly,
# Nearest to engine: fuel, piston, outboard, injection, gasoline, engined, lauder, lbf,
# Nearest to writers: esq, alamos, hosni, fiction, peerages, novelists, anthem, hoffmann,

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
